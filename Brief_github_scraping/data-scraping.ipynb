# %%
import pandas as pd
import requests as req
import time
import datetime
import ast
from github import Github

# %% [markdown]
# # requests model

# %%
access_token = "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"

# %%
start_date = datetime.date(2023, 6, 1)
end_date = datetime.date(2023, 6, 30)
delta = datetime.timedelta(days=1)

url = "https://api.github.com/search/repositories"
# Construct the headers with the access token
headers = {
    "Authorization": f"Bearer {access_token}",
    "Accept": "application/vnd.github.v3+json"  # Specify the API version
}
repositories = []
page = 1
while True:
    if start_date == datetime.date(2023, 6, 30):
        break
    while True:
        params = {
            "q": f"created:{start_date}",
            "sort": "stars",
            "order": "desc",
            "per_page": 100,
            "page": page
        }
        response = req.get(url, headers=headers, params=params)
        if response.status_code == 200:
            data = response.json()['items']
            repositories.extend([{
                'id':repo['id'],
                'full_name':repo['full_name'],
                'url':repo['html_url'],
                'clone_url':repo['clone_url'],
                'stargazers_count':repo['stargazers_count'],
                'language':repo['language'],
                'forks':repo['forks'],
                'created_at':repo['created_at'],
                'updated_at':repo['updated_at'],
                'pushed_at':repo['pushed_at'],
                'description':repo['description'],
                'languages_url':repo['languages_url'],
                'open_issues_count':repo['open_issues_count'],
                'contributors_url':repo['contributors_url'],
                'languages_url':repo['languages_url'],
                'commits_url':repo['commits_url'],
                'topics':repo['topics'],
                'license': repo['license']['name'] if repo['license'] else '',
                'owner':repo['owner']['type']
                } for repo in data])
            if "next" in response.links:
                page += 1
            else:
                print(f"the day {start_date} has been extracted.")
                break
        else:
            print(f"Error: {response.status_code} - {response.text}")
        time.sleep(1)
    if page == 10:
        page = 1
        start_date += delta
    time.sleep(1)
repositories
# Out:
# the day 2023-06-01 has been extracted.
# the day 2023-06-02 has been extracted.
# the day 2023-06-03 has been extracted.
# the day 2023-06-04 has been extracted.
# the day 2023-06-05 has been extracted.
# the day 2023-06-06 has been extracted.
# the day 2023-06-07 has been extracted.
# the day 2023-06-08 has been extracted.
# the day 2023-06-09 has been extracted.
# the day 2023-06-10 has been extracted.
# the day 2023-06-11 has been extracted.
# the day 2023-06-12 has been extracted.
# the day 2023-06-13 has been extracted.
# the day 2023-06-14 has been extracted.
# the day 2023-06-15 has been extracted.
# the day 2023-06-16 has been extracted.
# the day 2023-06-17 has been extracted.
# the day 2023-06-18 has been extracted.
# the day 2023-06-19 has been extracted.
# the day 2023-06-20 has been extracted.
# the day 2023-06-21 has been extracted.
# the day 2023-06-22 has been extracted.
# the day 2023-06-23 has been extracted.
# the day 2023-06-24 has been extracted.
# ...

# %%
df = pd.DataFrame.from_dict(repositories)
#df.to_csv('C:\\csv-data-collect\\github-2023_06_31.csv')

# %%
df = pd.read_csv('C:\\csv-data-collect\\github-2023_06_31.csv',index_col=0)
df.drop_duplicates()
drop_language_null = df[df['language'].isna()].index
df.drop(drop_language_null,inplace=True)
df.shape
# Out:
# (20432, 18)

# %%
contributors_info=[]
g = Github(access_token)
for index,row in df.iterrows():
        try:
            repo_name=row["full_name"]
            contributors=g.get_repo(repo_name).get_contributors()
            for contributor in contributors:
                contributors_info.append([repo_name,contributor.login,contributor.contributions])
        except:
            pass
contributors_info
# Out:
# [['SysCV/sam-hq', 'lkeab', 35],
#  ['SysCV/sam-hq', 'ymq2017', 1],
#  ['Not-Quite-RARBG/main', 'SlideMovies', 67],
#  ['Not-Quite-RARBG/main', '9pepsi', 22],
#  ['Not-Quite-RARBG/main', 'AnonymousWP', 11],
#  ['Not-Quite-RARBG/main', 'HankMooody', 6],
#  ['Not-Quite-RARBG/main', 'Keklul404', 3],
#  ['Not-Quite-RARBG/main', 'ejach', 2],
#  ['Not-Quite-RARBG/main', 'HighnessAtharva', 1],
#  ['damo-vilab/videocomposer', 'Steven-SWZhang', 3],
#  ['damo-vilab/videocomposer', 'alibaba-oss', 1],
#  ['mit-han-lab/llm-awq', 'tonylins', 4],
#  ['mit-han-lab/llm-awq', 'Sakits', 4],
#  ['mit-han-lab/llm-awq', 'kentang-mit', 3],
#  ['KasperskyLab/triangle_check', 'bzvr', 16],
#  ['KasperskyLab/triangle_check', 'igosha-kl', 3],
#  ['KasperskyLab/triangle_check', 'KLBot', 2],
#  ['KasperskyLab/triangle_check', 'iwiwsb', 2],
#  ['KasperskyLab/triangle_check', 'ykarpeev', 1],
#  ['icyguider/LightsOut', 'icyguider', 4],
#  ['haoosz/ViCo', 'haoosz', 20],
#  ['haoosz/ViCo', 'eltociear', 1],
# ...

# %%
columns = ["full_name", "contributor", "commit"]

df = pd.DataFrame(contributors_info, columns=columns)
#df.to_csv('C:\\csv-data-collect\\github-2023_06_31_contributors.csv', index=False)

# %%
df = pd.read_csv('C:\\csv-data-collect\\github-2023_06_31_contributors.csv')
df.loc[df['full_name'].str.contains('on')].groupby(['full_name']).apply(lambda x:x)
# Out:
#                                                                                 full_name
# full_name
# 001elijah/bc48-node-team-project-frontend 5253  001elijah/bc48-node-team-project-frontend  \
#                                           5254  001elijah/bc48-node-team-project-frontend
#                                           5255  001elijah/bc48-node-team-project-frontend
#                                           5256  001elijah/bc48-node-team-project-frontend
#                                           5257  001elijah/bc48-node-team-project-frontend
# ...                                                                                   ...
# yuzhongtao238910/apple-cli                597                  yuzhongtao238910/apple-cli
# yuzhongtao238910/vue3-webpack             516               yuzhongtao238910/vue3-webpack
# zaldivards/ContextQA                      7878                       zaldivards/ContextQA
# ...
