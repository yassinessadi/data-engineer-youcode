# %%
import pandas as pd
import requests as req
import time
import datetime

# %% [markdown]
# # requests model

# %%
access_token = "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"
headers = {
    'Authorization': f'Bearer {access_token}',
    'Accept': 'application/vnd.github.v3+json'
}
query_params = {
    'q': f'created:2023-01',
    'per_page':100,
    'page':2,
    'sort':'stars',
    'order':'desc'
}
base_url = 'https://api.github.com/search/repositories'
response = req.get(base_url, headers=headers, params=query_params)
response.json()['items'][0]['full_name']
# Out:
# 'supabase/supavisor'

# %%
access_token = "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"

# %%
# Replace with your personal access token
access_token = "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"

# API endpoint for retrieving repository information
url = "https://api.github.com/search/repositories"

# Construct the headers with the access token
headers = {
    "Authorization": f"Bearer {access_token}",
    "Accept": "application/vnd.github.v3+json"  # Specify the API version
}

def getDay(day):
    if day < 10:
        return str(f'0{day}')
    else:
        return day
repositories = []
page = 1
day = 1
while True:
    print(day)
    if day > 29:
        break
    while True:
        params = {
            "q": f"created:2023-04-{getDay(day)}",
            "sort": "stars",
            "order": "desc",
            "per_page": 100,
            "page": page
        }
        response = req.get(url, headers=headers, params=params)
        if response.status_code == 200:
            data = response.json()['items']
            repositories.extend([{
                'id':repo['id'],
                'full_name':repo['full_name'],
                'url':repo['html_url'],
                'clone_url':repo['clone_url'],
                'watchers_count':repo['watchers_count'],
                'stargazers_count':repo['stargazers_count'],
                'language':repo['language'],
                'forks':repo['forks'],
                'created_at':repo['created_at'],
                'updated_at':repo['updated_at'],
                'pushed_at':repo['pushed_at'],
                'description':repo['description'],
                'languages_url':repo['languages_url'],
                'open_issues_count':repo['open_issues_count'],
                'topics':repo['topics'],
                'license':repo['license']
                } for repo in data])
            if "next" in response.links:
                page += 1
            else:
                print(page)
                break
        else:
            print(f"Error: {response.status_code} - {response.text}")
        time.sleep(1)
    if page == 10:
        page = 1
        day += 1
    time.sleep(1)
repositories
# Out:
# 1
# 10
# 2
# 10
# 3
# 10
# 4
# 10
# 5
# 10
# 6
# 10
# 7
# 10
# 8
# 10
# 9
# 10
# 10
# 10
# 11
# 10
# 12
# 10
# 13
# 10
# 14
# 10
# 15
# 10
# 16
# 10
# 17
# 10
# 18
# 10
# 19
# 10
# 20
# 10
# 21
# 10
# 22
# 10
# 23
# 10
# 24
# 10
# 25
# 10
# 26
# 10
# 27
# 10
# 28
# 10
# 29
# 10
# 30
# [{'id': 622196323,
#   'full_name': 'FreedomIntelligence/LLMZoo',
#   'url': 'https://github.com/FreedomIntelligence/LLMZoo',
#   'clone_url': 'https://github.com/FreedomIntelligence/LLMZoo.git',
#   'watchers_count': 2333,
#   'stargazers_count': 2333,
#   'language': 'Python',
#   'forks': 150,
#   'created_at': '2023-04-01T12:08:23Z',
#   'updated_at': '2023-06-16T10:00:47Z',
#   'pushed_at': '2023-06-07T14:45:29Z',
#   'description': '⚡LLM Zoo is a project that provides data, models, and evaluation benchmark for large language models.⚡',
#   'languages_url': 'https://api.github.com/repos/FreedomIntelligence/LLMZoo/languages',
#   'open_issues_count': 22,
#   'topics': [],
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='}},
#  {'id': 622202906,
#   'full_name': 'Luodian/Otter',
#   'url': 'https://github.com/Luodian/Otter',
#   'clone_url': 'https://github.com/Luodian/Otter.git',
#   'watchers_count': 1884,
#   'stargazers_count': 1884,
#   'language': 'Python',
#   'forks': 200,
#   'created_at': '2023-04-01T12:31:49Z',
#   'updated_at': '2023-06-16T05:07:38Z',
#   'pushed_at': '2023-06-16T04:20:19Z',
#   'description': "🦦 Otter, a multi-modal model based on OpenFlamingo (open-sourced version of DeepMind's Flamingo), trained on MIMIC-IT and showcasing improved instruction-following and in-context learning ability.",
#   'languages_url': 'https://api.github.com/repos/Luodian/Otter/languages',
#   'open_issues_count': 13,
#   'topics': ['apple-vision-pro',
#    'artificial-inteligence',
#    'chatgpt',
#    'deep-learning',
#    'egocentric-vision',
#    'embodied',
#    'embodied-ai',
#    'foundation-models',
#    'gpt-4',
#    'instruction-tuning',
#    'large-scale-models',
#    'machine-learning',
#    'multi-modality',
#    'visual-language-learning'],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 622081419,
#   'full_name': 'supabase-community/nextjs-openai-doc-search',
#   'url': 'https://github.com/supabase-community/nextjs-openai-doc-search',
#   'clone_url': 'https://github.com/supabase-community/nextjs-openai-doc-search.git',
#   'watchers_count': 975,
#   'stargazers_count': 975,
#   'language': 'TypeScript',
#   'forks': 175,
#   'created_at': '2023-04-01T04:12:56Z',
#   'updated_at': '2023-06-16T08:47:32Z',
#   'pushed_at': '2023-06-09T16:50:52Z',
#   'description': 'Template for building your own custom ChatGPT style doc search powered by Next.js, OpenAI, and Supabase.',
#   'languages_url': 'https://api.github.com/repos/supabase-community/nextjs-openai-doc-search/languages',
#   'open_issues_count': 3,
#   'topics': ['ai',
#    'chatgpt',
#    'nextjs',
#    'openai',
#    'postgres',
#    'supabase',
#    'template',
#    'vector-search'],
#   'license': None},
#  {'id': 622130557,
#   'full_name': 'Torantulino/AI-Functions',
#   'url': 'https://github.com/Torantulino/AI-Functions',
#   'clone_url': 'https://github.com/Torantulino/AI-Functions.git',
#   'watchers_count': 858,
#   'stargazers_count': 858,
#   'language': 'Python',
#   'forks': 103,
#   'created_at': '2023-04-01T07:57:15Z',
#   'updated_at': '2023-06-15T03:18:47Z',
#   'pushed_at': '2023-04-26T10:54:32Z',
#   'description': 'AI-Powered Function Magic: Never code again with GPT models!',
#   'languages_url': 'https://api.github.com/repos/Torantulino/AI-Functions/languages',
#   'open_issues_count': 13,
#   'topics': ['chatgpt', 'gpt-3', 'gpt4', 'openai', 'openai-api', 'python'],
#   'license': None},
#  {'id': 622091971,
#   'full_name': 'unit-mesh/unit-minions',
#   'url': 'https://github.com/unit-mesh/unit-minions',
#   'clone_url': 'https://github.com/unit-mesh/unit-minions.git',
#   'watchers_count': 703,
#   'stargazers_count': 703,
#   'language': 'Jupyter Notebook',
#   'forks': 77,
#   'created_at': '2023-04-01T05:05:42Z',
#   'updated_at': '2023-06-16T03:14:56Z',
#   'pushed_at': '2023-05-22T02:42:34Z',
#   'description': '《AI 研发提效研究：自己动手训练 LoRA》，包含 Llama  （Alpaca LoRA）模型、ChatGLM （ChatGLM Tuning）相关 Lora 的训练。训练内容：用户故事生成、测试代码生成、代码辅助生成、文本转 SQL、文本生成代码……',
#   'languages_url': 'https://api.github.com/repos/unit-mesh/unit-minions/languages',
#   'open_issues_count': 0,
#   'topics': ['llm', 'lora'],
#   'license': None},
#  {'id': 622147274,
#   'full_name': 'THUDM/ImageReward',
#   'url': 'https://github.com/THUDM/ImageReward',
#   'clone_url': 'https://github.com/THUDM/ImageReward.git',
#   'watchers_count': 475,
#   'stargazers_count': 475,
#   'language': 'Python',
#   'forks': 26,
#   'created_at': '2023-04-01T09:04:17Z',
#   'updated_at': '2023-06-16T06:23:15Z',
#   'pushed_at': '2023-06-08T01:57:49Z',
#   'description': 'ImageReward: Learning and Evaluating Human Preferences for Text-to-image Generation',
#   'languages_url': 'https://api.github.com/repos/THUDM/ImageReward/languages',
#   'open_issues_count': 9,
#   'topics': ['diffusion-models',
#    'generative-model',
#    'human-preferences',
#    'rlhf'],
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='}},
#  {'id': 622352364,
#   'full_name': 'simonw/llm',
#   'url': 'https://github.com/simonw/llm',
#   'clone_url': 'https://github.com/simonw/llm.git',
#   'watchers_count': 443,
#   'stargazers_count': 443,
#   'language': 'Python',
#   'forks': 8,
#   'created_at': '2023-04-01T21:16:57Z',
#   'updated_at': '2023-06-16T09:54:59Z',
#   'pushed_at': '2023-06-16T08:06:33Z',
#   'description': 'Access large language models from the command-line',
#   'languages_url': 'https://api.github.com/repos/simonw/llm/languages',
#   'open_issues_count': 13,
#   'topics': [],
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='}},
#  {'id': 622045677,
#   'full_name': 'igorbrigadir/awesome-twitter-algo',
#   'url': 'https://github.com/igorbrigadir/awesome-twitter-algo',
#   'clone_url': 'https://github.com/igorbrigadir/awesome-twitter-algo.git',
#   'watchers_count': 442,
#   'stargazers_count': 442,
#   'language': None,
#   'forks': 24,
#   'created_at': '2023-04-01T01:06:53Z',
#   'updated_at': '2023-06-16T08:02:43Z',
#   'pushed_at': '2023-04-15T17:47:28Z',
#   'description': 'The release of the Twitter algorithm, annotated for recsys',
#   'languages_url': 'https://api.github.com/repos/igorbrigadir/awesome-twitter-algo/languages',
#   'open_issues_count': 2,
#   'topics': [],
#   'license': None},
#  {'id': 622144784,
#   'full_name': 'diStyApps/seait',
#   'url': 'https://github.com/diStyApps/seait',
#   'clone_url': 'https://github.com/diStyApps/seait.git',
#   'watchers_count': 427,
#   'stargazers_count': 427,
#   'language': 'Python',
#   'forks': 16,
#   'created_at': '2023-04-01T08:55:21Z',
#   'updated_at': '2023-06-16T06:31:42Z',
#   'pushed_at': '2023-04-30T01:00:53Z',
#   'description': 'SEAIT is a user-friendly application that simplifies the installation process of AI-related projects',
#   'languages_url': 'https://api.github.com/repos/diStyApps/seait/languages',
#   'open_issues_count': 5,
#   'topics': ['ai',
#    'artificial-intelligence',
#    'automatic1111',
#    'comfyui',
#    'install',
#    'installation',
#    'installer',
#    'invokeai',
#    'kohya-webui',
#    'large-language-models',
#    'llm',
#    'seait',
#    'stable-diffusion',
#    'stable-diffusion-webui',
#    'super-easy-ai-installer-tool',
#    'text-generation-webui',
#    'tool',
#    'webui'],
#   'license': None},
#  {'id': 622050087,
#   'full_name': 'ByteStorage/FlyDB',
#   'url': 'https://github.com/ByteStorage/FlyDB',
#   'clone_url': 'https://github.com/ByteStorage/FlyDB.git',
#   'watchers_count': 420,
#   'stargazers_count': 420,
#   'language': 'Go',
#   'forks': 54,
#   'created_at': '2023-04-01T01:30:37Z',
#   'updated_at': '2023-06-16T02:11:06Z',
#   'pushed_at': '2023-06-15T11:53:29Z',
#   'description': 'The high-performance kv storage engine based on bitcask paper made in golang',
#   'languages_url': 'https://api.github.com/repos/ByteStorage/FlyDB/languages',
#   'open_issues_count': 30,
#   'topics': ['database',
#    'flydb',
#    'go',
#    'golang',
#    'key-value',
#    'kv-store',
#    'raft',
#    'redis'],
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='}},
#  {'id': 622335595,
#   'full_name': 'tsale/EDR-Telemetry',
#   'url': 'https://github.com/tsale/EDR-Telemetry',
#   'clone_url': 'https://github.com/tsale/EDR-Telemetry.git',
#   'watchers_count': 399,
#   'stargazers_count': 399,
#   'language': 'PowerShell',
#   'forks': 47,
#   'created_at': '2023-04-01T20:02:33Z',
#   'updated_at': '2023-06-16T08:47:38Z',
#   'pushed_at': '2023-06-16T05:52:02Z',
#   'description': 'This project aims to compare and evaluate the telemetry of various EDR products.',
#   'languages_url': 'https://api.github.com/repos/tsale/EDR-Telemetry/languages',
#   'open_issues_count': 6,
#   'topics': [],
#   'license': None},
#  {'id': 622153078,
#   'full_name': 'lxfater/LLMR-NLUP',
#   'url': 'https://github.com/lxfater/LLMR-NLUP',
#   'clone_url': 'https://github.com/lxfater/LLMR-NLUP.git',
#   'watchers_count': 379,
#   'stargazers_count': 379,
#   'language': 'Vue',
#   'forks': 57,
#   'created_at': '2023-04-01T09:25:43Z',
#   'updated_at': '2023-06-05T04:56:54Z',
#   'pushed_at': '2023-05-09T08:15:19Z',
#   'description': 'A quick demo of Natural-Language-UI-Programming, implemented purely on the front end and powered by GPT-3.5',
#   'languages_url': 'https://api.github.com/repos/lxfater/LLMR-NLUP/languages',
#   'open_issues_count': 1,
#   'topics': [],
#   'license': {'key': 'gpl-3.0',
#    'name': 'GNU General Public License v3.0',
#    'spdx_id': 'GPL-3.0',
#    'url': 'https://api.github.com/licenses/gpl-3.0',
#    'node_id': 'MDc6TGljZW5zZTk='}},
#  {'id': 622094213,
#   'full_name': 'Bryley/neoai.nvim',
#   'url': 'https://github.com/Bryley/neoai.nvim',
#   'clone_url': 'https://github.com/Bryley/neoai.nvim.git',
#   'watchers_count': 343,
#   'stargazers_count': 343,
#   'language': 'Lua',
#   'forks': 28,
#   'created_at': '2023-04-01T05:17:13Z',
#   'updated_at': '2023-06-16T05:04:30Z',
#   'pushed_at': '2023-06-07T13:00:03Z',
#   'description': 'Neovim plugin for intracting with GPT models from OpenAI',
#   'languages_url': 'https://api.github.com/repos/Bryley/neoai.nvim/languages',
#   'open_issues_count': 23,
#   'topics': ['chatgpt',
#    'gpt',
#    'gpt-4',
#    'gpt3-turbo',
#    'neovim',
#    'neovim-plugin',
#    'nvim',
#    'nvim-plugin',
#    'openai'],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 622327594,
#   'full_name': 'tsoding/c.php',
#   'url': 'https://github.com/tsoding/c.php',
#   'clone_url': 'https://github.com/tsoding/c.php.git',
#   'watchers_count': 275,
#   'stargazers_count': 275,
#   'language': 'PHP',
#   'forks': 10,
#   'created_at': '2023-04-01T19:27:30Z',
#   'updated_at': '2023-06-15T17:30:16Z',
#   'pushed_at': '2023-04-18T22:04:37Z',
#   'description': 'C to Python compiler in PHP',
#   'languages_url': 'https://api.github.com/repos/tsoding/c.php/languages',
#   'open_issues_count': 3,
#   'topics': [],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 622164768,
#   'full_name': 'NsLearning/LangHelper',
#   'url': 'https://github.com/NsLearning/LangHelper',
#   'clone_url': 'https://github.com/NsLearning/LangHelper.git',
#   'watchers_count': 263,
#   'stargazers_count': 263,
#   'language': 'Rust',
#   'forks': 20,
#   'created_at': '2023-04-01T10:09:47Z',
#   'updated_at': '2023-06-11T18:45:31Z',
#   'pushed_at': '2023-05-19T05:48:23Z',
#   'description': 'Striving to create a great Application with full functions of learning languages by ChatGPT, TTS, STT and other awesome AI models, supports talking, speaking assessment, memorizing words with contexts, Listening test, so on.',
#   'languages_url': 'https://api.github.com/repos/NsLearning/LangHelper/languages',
#   'open_issues_count': 0,
#   'topics': ['ai',
#    'asr',
#    'assessment',
#    'chatgpt',
#    'ielts',
#    'language-learning',
#    'speech',
#    'speech-recognition',
#    'speech-to-text',
#    'stt',
#    'toefl',
#    'tts',
#    'words'],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 622229882,
#   'full_name': 'DeSinc/SallyBot',
#   'url': 'https://github.com/DeSinc/SallyBot',
#   'clone_url': 'https://github.com/DeSinc/SallyBot.git',
#   'watchers_count': 252,
#   'stargazers_count': 252,
#   'language': 'C#',
#   'forks': 39,
#   'created_at': '2023-04-01T14:02:05Z',
#   'updated_at': '2023-06-14T20:58:58Z',
#   'pushed_at': '2023-06-09T13:09:23Z',
#   'description': 'AI Chatbot coded in Discord.net C#',
#   'languages_url': 'https://api.github.com/repos/DeSinc/SallyBot/languages',
#   'open_issues_count': 1,
#   'topics': [],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 622205108,
#   'full_name': 'ClickHouse/NoiSQL',
#   'url': 'https://github.com/ClickHouse/NoiSQL',
#   'clone_url': 'https://github.com/ClickHouse/NoiSQL.git',
#   'watchers_count': 238,
#   'stargazers_count': 238,
#   'language': 'SQL',
#   'forks': 1,
#   'created_at': '2023-04-01T12:39:59Z',
#   'updated_at': '2023-06-15T08:24:27Z',
#   'pushed_at': '2023-04-16T22:10:25Z',
#   'description': 'NoiSQL — Generating Music With SQL Queries',
#   'languages_url': 'https://api.github.com/repos/ClickHouse/NoiSQL/languages',
#   'open_issues_count': 1,
#   'topics': [],
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='}},
#  {'id': 622348470,
#   'full_name': 'nisshak12/awesome-chatgpt-plugins',
#   'url': 'https://github.com/nisshak12/awesome-chatgpt-plugins',
#   'clone_url': 'https://github.com/nisshak12/awesome-chatgpt-plugins.git',
#   'watchers_count': 235,
#   'stargazers_count': 235,
#   'language': None,
#   'forks': 0,
#   'created_at': '2023-04-01T20:59:05Z',
#   'updated_at': '2023-06-05T22:55:52Z',
#   'pushed_at': '2023-04-01T20:59:27Z',
#   'description': 'An up-to-date collection of ChatGPT plugins and evolvements',
#   'languages_url': 'https://api.github.com/repos/nisshak12/awesome-chatgpt-plugins/languages',
#   'open_issues_count': 1,
#   'topics': ['awesome',
#    'awesome-list',
#    'chatgpt',
#    'chatgpt-plugins',
#    'openai'],
#   'license': None},
#  {'id': 622075927,
#   'full_name': 'zjunlp/KnowLM',
#   'url': 'https://github.com/zjunlp/KnowLM',
#   'clone_url': 'https://github.com/zjunlp/KnowLM.git',
#   'watchers_count': 221,
#   'stargazers_count': 221,
#   'language': 'Python',
#   'forks': 13,
#   'created_at': '2023-04-01T03:45:31Z',
#   'updated_at': '2023-06-16T09:06:38Z',
#   'pushed_at': '2023-06-16T00:59:48Z',
#   'description': 'Knowledgable Large Language Model Series.',
#   'languages_url': 'https://api.github.com/repos/zjunlp/KnowLM/languages',
#   'open_issues_count': 3,
#   'topics': ['bilingual',
#    'chinese',
#    'deep-learning',
#    'deepspeed',
#    'english',
#    'gpt-3',
#    'instruction-following',
#    'instruction-tuning',
#    'instructions',
#    'knowledge',
#    'knowllm',
#    'language-model',
#    'large-language-models',
#    'llama',
#    'lora',
#    'models',
#    'pre-trained-language-models',
#    'pre-trained-model',
#    'pre-training',
#    'reasoning'],
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='}},
#  {'id': 622190086,
#   'full_name': 'morpheuslord/QuadraInspect',
#   'url': 'https://github.com/morpheuslord/QuadraInspect',
#   'clone_url': 'https://github.com/morpheuslord/QuadraInspect.git',
#   'watchers_count': 218,
#   'stargazers_count': 218,
#   'language': 'Python',
#   'forks': 37,
#   'created_at': '2023-04-01T11:45:36Z',
#   'updated_at': '2023-06-11T16:21:19Z',
#   'pushed_at': '2023-05-14T07:33:34Z',
#   'description': 'QuadraInspect is an Android framework that integrates AndroPass, APKUtil, and MobFS, providing a powerful tool for analyzing the security of Android applications. ',
#   'languages_url': 'https://api.github.com/repos/morpheuslord/QuadraInspect/languages',
#   'open_issues_count': 1,
#   'topics': ['android',
#    'android-framework',
#    'android-hacking',
#    'android-hacking-tools',
#    'apk',
#    'apk-analysis',
#    'apk-analyzer'],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 622179820,
#   'full_name': 'SebLague/Ray-Tracing',
#   'url': 'https://github.com/SebLague/Ray-Tracing',
#   'clone_url': 'https://github.com/SebLague/Ray-Tracing.git',
#   'watchers_count': 203,
#   'stargazers_count': 203,
#   'language': 'C#',
#   'forks': 12,
#   'created_at': '2023-04-01T11:06:29Z',
#   'updated_at': '2023-06-11T18:46:04Z',
#   'pushed_at': '2023-04-15T10:10:28Z',
#   'description': None,
#   'languages_url': 'https://api.github.com/repos/SebLague/Ray-Tracing/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 622061871,
#   'full_name': 'ZhangHanDong/rustchat',
#   'url': 'https://github.com/ZhangHanDong/rustchat',
#   'clone_url': 'https://github.com/ZhangHanDong/rustchat.git',
#   'watchers_count': 199,
#   'stargazers_count': 199,
#   'language': None,
#   'forks': 23,
#   'created_at': '2023-04-01T02:34:34Z',
#   'updated_at': '2023-06-09T09:34:56Z',
#   'pushed_at': '2023-05-01T10:27:07Z',
#   'description': 'Develop GPT as a "magic" system for assisting Rust learning.',
#   'languages_url': 'https://api.github.com/repos/ZhangHanDong/rustchat/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 622175439,
#   'full_name': 'puskal-khadka/TikTok-Compose',
#   'url': 'https://github.com/puskal-khadka/TikTok-Compose',
#   'clone_url': 'https://github.com/puskal-khadka/TikTok-Compose.git',
#   'watchers_count': 187,
#   'stargazers_count': 187,
#   'language': 'Kotlin',
#   'forks': 26,
#   'created_at': '2023-04-01T10:49:44Z',
#   'updated_at': '2023-06-16T07:55:07Z',
#   'pushed_at': '2023-04-15T15:14:19Z',
#   'description': 'TikTok clone Android app built with jetpack compose following clean architecture & modularization.',
#   'languages_url': 'https://api.github.com/repos/puskal-khadka/TikTok-Compose/languages',
#   'open_issues_count': 0,
#   'topics': ['android',
#    'camerax',
#    'exoplayer',
#    'jetpack-compose',
#    'tiktok',
#    'tiktok-clone'],
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='}},
#  {'id': 622134485,
#   'full_name': 'Knowly-ai/langtorch',
#   'url': 'https://github.com/Knowly-ai/langtorch',
#   'clone_url': 'https://github.com/Knowly-ai/langtorch.git',
#   'watchers_count': 179,
#   'stargazers_count': 179,
#   'language': 'Java',
#   'forks': 27,
#   'created_at': '2023-04-01T08:13:06Z',
#   'updated_at': '2023-06-16T09:12:39Z',
#   'pushed_at': '2023-06-16T07:22:53Z',
#   'description': '🔥 Building composable LLM applications & workflow with Java.',
#   'languages_url': 'https://api.github.com/repos/Knowly-ai/langtorch/languages',
#   'open_issues_count': 16,
#   'topics': ['ai',
#    'chain-of-thought',
#    'chatgpt',
#    'chatgpt-plugins',
#    'java',
#    'langchain',
#    'langtorch',
#    'large-language-models',
#    'llm',
#    'openai',
#    'semantic-kernel'],
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='}},
#  {'id': 622187167,
#   'full_name': 'gitwonk/gitwonk',
#   'url': 'https://github.com/gitwonk/gitwonk',
#   'clone_url': 'https://github.com/gitwonk/gitwonk.git',
#   'watchers_count': 176,
#   'stargazers_count': 176,
#   'language': 'TypeScript',
#   'forks': 3,
#   'created_at': '2023-04-01T11:34:22Z',
#   'updated_at': '2023-06-16T04:15:29Z',
#   'pushed_at': '2023-06-02T18:01:04Z',
#   'description': 'The open source GitBook, Confluence, and Archbee alternative. Write technical docs like never before 🐙',
#   'languages_url': 'https://api.github.com/repos/gitwonk/gitwonk/languages',
#   'open_issues_count': 2,
#   'topics': [],
#   'license': {'key': 'agpl-3.0',
#    'name': 'GNU Affero General Public License v3.0',
#    'spdx_id': 'AGPL-3.0',
#    'url': 'https://api.github.com/licenses/agpl-3.0',
#    'node_id': 'MDc6TGljZW5zZTE='}},
#  {'id': 622140320,
#   'full_name': 'datafuselabs/askbend',
#   'url': 'https://github.com/datafuselabs/askbend',
#   'clone_url': 'https://github.com/datafuselabs/askbend.git',
#   'watchers_count': 174,
#   'stargazers_count': 174,
#   'language': 'TypeScript',
#   'forks': 10,
#   'created_at': '2023-04-01T08:37:12Z',
#   'updated_at': '2023-06-09T07:32:15Z',
#   'pushed_at': '2023-06-08T00:13:10Z',
#   'description': 'AskBend: SQL-based Knowledge Base Search and Completion using Databend',
#   'languages_url': 'https://api.github.com/repos/datafuselabs/askbend/languages',
#   'open_issues_count': 3,
#   'topics': [],
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='}},
#  {'id': 622363320,
#   'full_name': 'BelieveDiffusion/tutorials',
#   'url': 'https://github.com/BelieveDiffusion/tutorials',
#   'clone_url': 'https://github.com/BelieveDiffusion/tutorials.git',
#   'watchers_count': 144,
#   'stargazers_count': 144,
#   'language': None,
#   'forks': 13,
#   'created_at': '2023-04-01T22:12:14Z',
#   'updated_at': '2023-06-14T22:26:33Z',
#   'pushed_at': '2023-04-22T22:03:58Z',
#   'description': 'A collection of tutorials about training and generating with Stable Diffusion.',
#   'languages_url': 'https://api.github.com/repos/BelieveDiffusion/tutorials/languages',
#   'open_issues_count': 1,
#   'topics': ['ai', 'stable-diffusion', 'textual-inversion'],
#   'license': None},
#  {'id': 622262666,
#   'full_name': 'chuanyang-Zheng/Progressive-Hint',
#   'url': 'https://github.com/chuanyang-Zheng/Progressive-Hint',
#   'clone_url': 'https://github.com/chuanyang-Zheng/Progressive-Hint.git',
#   'watchers_count': 134,
#   'stargazers_count': 134,
#   'language': 'Python',
#   'forks': 3,
#   'created_at': '2023-04-01T15:41:58Z',
#   'updated_at': '2023-06-15T07:59:48Z',
#   'pushed_at': '2023-06-05T02:49:03Z',
#   'description': 'This is the official implementation of "Progressive-Hint Prompting Improves Reasoning in Large Language Models"',
#   'languages_url': 'https://api.github.com/repos/chuanyang-Zheng/Progressive-Hint/languages',
#   'open_issues_count': 2,
#   'topics': [],
#   'license': None},
#  {'id': 622205555,
#   'full_name': 'mist-project/mist',
#   'url': 'https://github.com/mist-project/mist',
#   'clone_url': 'https://github.com/mist-project/mist.git',
#   'watchers_count': 134,
#   'stargazers_count': 134,
#   'language': 'Python',
#   'forks': 9,
#   'created_at': '2023-04-01T12:41:28Z',
#   'updated_at': '2023-06-16T09:45:37Z',
#   'pushed_at': '2023-05-29T05:02:48Z',
#   'description': None,
#   'languages_url': 'https://api.github.com/repos/mist-project/mist/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': {'key': 'gpl-3.0',
#    'name': 'GNU General Public License v3.0',
#    'spdx_id': 'GPL-3.0',
#    'url': 'https://api.github.com/licenses/gpl-3.0',
#    'node_id': 'MDc6TGljZW5zZTk='}},
#  {'id': 622072944,
#   'full_name': 'pulumi/pulumi-ai',
#   'url': 'https://github.com/pulumi/pulumi-ai',
#   'clone_url': 'https://github.com/pulumi/pulumi-ai.git',
#   'watchers_count': 129,
#   'stargazers_count': 129,
#   'language': 'TypeScript',
#   'forks': 2,
#   'created_at': '2023-04-01T03:29:58Z',
#   'updated_at': '2023-06-15T19:23:48Z',
#   'pushed_at': '2023-04-26T22:04:32Z',
#   'description': None,
#   'languages_url': 'https://api.github.com/repos/pulumi/pulumi-ai/languages',
#   'open_issues_count': 21,
#   'topics': [],
#   'license': None},
#  {'id': 622323001,
#   'full_name': 'pmulard/machine-learning-specialization-andrew-ng',
#   'url': 'https://github.com/pmulard/machine-learning-specialization-andrew-ng',
#   'clone_url': 'https://github.com/pmulard/machine-learning-specialization-andrew-ng.git',
#   'watchers_count': 123,
#   'stargazers_count': 123,
#   'language': 'Jupyter Notebook',
#   'forks': 8,
#   'created_at': '2023-04-01T19:08:54Z',
#   'updated_at': '2023-06-16T08:31:14Z',
#   'pushed_at': '2023-06-08T16:48:57Z',
#   'description': "A collection of notes and implementations of machine learning algorithms from Andrew Ng's machine learning specialization.",
#   'languages_url': 'https://api.github.com/repos/pmulard/machine-learning-specialization-andrew-ng/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 622042668,
#   'full_name': 'nix-community/haumea',
#   'url': 'https://github.com/nix-community/haumea',
#   'clone_url': 'https://github.com/nix-community/haumea.git',
#   'watchers_count': 122,
#   'stargazers_count': 122,
#   'language': 'Nix',
#   'forks': 2,
#   'created_at': '2023-04-01T00:50:18Z',
#   'updated_at': '2023-06-16T09:14:41Z',
#   'pushed_at': '2023-06-05T23:24:08Z',
#   'description': 'Filesystem-based module system for Nix [maintainer=@figsoda]',
#   'languages_url': 'https://api.github.com/repos/nix-community/haumea/languages',
#   'open_issues_count': 2,
#   'topics': ['auto',
#    'flake',
#    'flakes',
#    'hierarchy',
#    'import',
#    'nix',
#    'visibility'],
#   'license': {'key': 'mpl-2.0',
#    'name': 'Mozilla Public License 2.0',
#    'spdx_id': 'MPL-2.0',
#    'url': 'https://api.github.com/licenses/mpl-2.0',
#    'node_id': 'MDc6TGljZW5zZTE0'}},
#  {'id': 622185008,
#   'full_name': 'pingdotgg/markerthing',
#   'url': 'https://github.com/pingdotgg/markerthing',
#   'clone_url': 'https://github.com/pingdotgg/markerthing.git',
#   'watchers_count': 120,
#   'stargazers_count': 120,
#   'language': 'TypeScript',
#   'forks': 19,
#   'created_at': '2023-04-01T11:26:09Z',
#   'updated_at': '2023-06-14T08:11:25Z',
#   'pushed_at': '2023-04-16T03:35:16Z',
#   'description': 'markerthing',
#   'languages_url': 'https://api.github.com/repos/pingdotgg/markerthing/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 622102745,
#   'full_name': 'mcay23/hound',
#   'url': 'https://github.com/mcay23/hound',
#   'clone_url': 'https://github.com/mcay23/hound.git',
#   'watchers_count': 119,
#   'stargazers_count': 119,
#   'language': 'TypeScript',
#   'forks': 2,
#   'created_at': '2023-04-01T05:58:39Z',
#   'updated_at': '2023-06-04T04:47:48Z',
#   'pushed_at': '2023-04-08T20:19:33Z',
#   'description': 'Track TV Shows, Movies, etc.',
#   'languages_url': 'https://api.github.com/repos/mcay23/hound/languages',
#   'open_issues_count': 3,
#   'topics': [],
#   'license': {'key': 'gpl-3.0',
#    'name': 'GNU General Public License v3.0',
#    'spdx_id': 'GPL-3.0',
#    'url': 'https://api.github.com/licenses/gpl-3.0',
#    'node_id': 'MDc6TGljZW5zZTk='}},
#  {'id': 622134207,
#   'full_name': 'k8sgpt-ai/k8sgpt-operator',
#   'url': 'https://github.com/k8sgpt-ai/k8sgpt-operator',
#   'clone_url': 'https://github.com/k8sgpt-ai/k8sgpt-operator.git',
#   'watchers_count': 117,
#   'stargazers_count': 117,
#   'language': 'Go',
#   'forks': 24,
#   'created_at': '2023-04-01T08:11:57Z',
#   'updated_at': '2023-06-15T05:34:25Z',
#   'pushed_at': '2023-06-15T22:09:04Z',
#   'description': 'Automatic SRE Superpowers within your Kubernetes cluster',
#   'languages_url': 'https://api.github.com/repos/k8sgpt-ai/k8sgpt-operator/languages',
#   'open_issues_count': 15,
#   'topics': ['devops', 'kubernetes', 'openai', 'sre', 'tooling'],
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='}},
#  {'id': 622163788,
#   'full_name': 'tunds/SwiftUI-Navigation-Multiplatform-Example',
#   'url': 'https://github.com/tunds/SwiftUI-Navigation-Multiplatform-Example',
#   'clone_url': 'https://github.com/tunds/SwiftUI-Navigation-Multiplatform-Example.git',
#   'watchers_count': 110,
#   'stargazers_count': 110,
#   'language': 'Swift',
#   'forks': 1,
#   'created_at': '2023-04-01T10:06:02Z',
#   'updated_at': '2023-06-07T18:46:21Z',
#   'pushed_at': '2023-04-25T10:43:45Z',
#   'description': "This repo a 100% SwiftUI app showcasing examples of navigation, Multiplatform support & deep linking using the new NavigationStack & NavigationSplitView API's",
#   'languages_url': 'https://api.github.com/repos/tunds/SwiftUI-Navigation-Multiplatform-Example/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 622269742,
#   'full_name': 'ParisNeo/Gpt4All-webui',
#   'url': 'https://github.com/ParisNeo/Gpt4All-webui',
#   'clone_url': 'https://github.com/ParisNeo/Gpt4All-webui.git',
#   'watchers_count': 106,
#   'stargazers_count': 106,
#   'language': 'CSS',
#   'forks': 24,
#   'created_at': '2023-04-01T16:04:28Z',
#   'updated_at': '2023-06-16T05:04:47Z',
#   'pushed_at': '2023-05-30T09:22:41Z',
#   'description': 'A web user interface for GPT4All',
#   'languages_url': 'https://api.github.com/repos/ParisNeo/Gpt4All-webui/languages',
#   'open_issues_count': 11,
#   'topics': ['machine-learning', 'natural-language-processing'],
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='}},
#  {'id': 622054474,
#   'full_name': 'v50-one/CloudflareSpeedTest-api',
#   'url': 'https://github.com/v50-one/CloudflareSpeedTest-api',
#   'clone_url': 'https://github.com/v50-one/CloudflareSpeedTest-api.git',
#   'watchers_count': 104,
#   'stargazers_count': 104,
#   'language': 'Go',
#   'forks': 23,
#   'created_at': '2023-04-01T01:54:47Z',
#   'updated_at': '2023-06-16T07:28:44Z',
#   'pushed_at': '2023-06-11T15:49:13Z',
#   'description': None,
#   'languages_url': 'https://api.github.com/repos/v50-one/CloudflareSpeedTest-api/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': {'key': 'gpl-3.0',
#    'name': 'GNU General Public License v3.0',
#    'spdx_id': 'GPL-3.0',
#    'url': 'https://api.github.com/licenses/gpl-3.0',
#    'node_id': 'MDc6TGljZW5zZTk='}},
#  {'id': 622234196,
#   'full_name': 'mingyuan-zhang/ReMoDiffuse',
#   'url': 'https://github.com/mingyuan-zhang/ReMoDiffuse',
#   'clone_url': 'https://github.com/mingyuan-zhang/ReMoDiffuse.git',
#   'watchers_count': 104,
#   'stargazers_count': 104,
#   'language': None,
#   'forks': 1,
#   'created_at': '2023-04-01T14:15:33Z',
#   'updated_at': '2023-06-15T15:22:37Z',
#   'pushed_at': '2023-04-04T02:33:10Z',
#   'description': 'ReMoDiffuse: Retrieval-Augmented Motion Diffusion Model',
#   'languages_url': 'https://api.github.com/repos/mingyuan-zhang/ReMoDiffuse/languages',
#   'open_issues_count': 1,
#   'topics': [],
#   'license': {'key': 'other',
#    'name': 'Other',
#    'spdx_id': 'NOASSERTION',
#    'url': None,
#    'node_id': 'MDc6TGljZW5zZTA='}},
#  {'id': 622371256,
#   'full_name': 'Intuitive-Systems/react-agent-ts',
#   'url': 'https://github.com/Intuitive-Systems/react-agent-ts',
#   'clone_url': 'https://github.com/Intuitive-Systems/react-agent-ts.git',
#   'watchers_count': 102,
#   'stargazers_count': 102,
#   'language': 'TypeScript',
#   'forks': 7,
#   'created_at': '2023-04-01T22:53:51Z',
#   'updated_at': '2023-06-05T16:16:05Z',
#   'pushed_at': '2023-04-09T18:55:45Z',
#   'description': None,
#   'languages_url': 'https://api.github.com/repos/Intuitive-Systems/react-agent-ts/languages',
#   'open_issues_count': 1,
#   'topics': [],
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='}},
#  {'id': 622261770,
#   'full_name': 'ExtremeElectronics/PicoCray',
#   'url': 'https://github.com/ExtremeElectronics/PicoCray',
#   'clone_url': 'https://github.com/ExtremeElectronics/PicoCray.git',
#   'watchers_count': 95,
#   'stargazers_count': 95,
#   'language': 'C',
#   'forks': 4,
#   'created_at': '2023-04-01T15:39:09Z',
#   'updated_at': '2023-06-06T16:23:46Z',
#   'pushed_at': '2023-04-25T15:16:23Z',
#   'description': 'A system for running distributed code over multiple PI Picos ',
#   'languages_url': 'https://api.github.com/repos/ExtremeElectronics/PicoCray/languages',
#   'open_issues_count': 2,
#   'topics': [],
#   'license': {'key': 'other',
#    'name': 'Other',
#    'spdx_id': 'NOASSERTION',
#    'url': None,
#    'node_id': 'MDc6TGljZW5zZTA='}},
#  {'id': 622072830,
#   'full_name': 'op7418/Mijourney-enhanced',
#   'url': 'https://github.com/op7418/Mijourney-enhanced',
#   'clone_url': 'https://github.com/op7418/Mijourney-enhanced.git',
#   'watchers_count': 95,
#   'stargazers_count': 95,
#   'language': 'JavaScript',
#   'forks': 8,
#   'created_at': '2023-04-01T03:29:22Z',
#   'updated_at': '2023-05-28T04:58:18Z',
#   'pushed_at': '2023-04-20T16:34:26Z',
#   'description': 'Translate Midjourney-specific locations and enhance the site experience',
#   'languages_url': 'https://api.github.com/repos/op7418/Mijourney-enhanced/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': {'key': 'gpl-2.0',
#    'name': 'GNU General Public License v2.0',
#    'spdx_id': 'GPL-2.0',
#    'url': 'https://api.github.com/licenses/gpl-2.0',
#    'node_id': 'MDc6TGljZW5zZTg='}},
#  {'id': 622225668,
#   'full_name': 'cqcore/Website-OSINT',
#   'url': 'https://github.com/cqcore/Website-OSINT',
#   'clone_url': 'https://github.com/cqcore/Website-OSINT.git',
#   'watchers_count': 84,
#   'stargazers_count': 84,
#   'language': None,
#   'forks': 6,
#   'created_at': '2023-04-01T13:48:35Z',
#   'updated_at': '2023-06-15T08:17:58Z',
#   'pushed_at': '2023-05-25T14:45:29Z',
#   'description': 'You will find a wealth of resources to help with your Website investigations.',
#   'languages_url': 'https://api.github.com/repos/cqcore/Website-OSINT/languages',
#   'open_issues_count': 0,
#   'topics': ['analytics',
#    'archives',
#    'dns',
#    'osint',
#    'security',
#    'url-shortener',
#    'website',
#    'whois-lookup'],
#   'license': None},
#  {'id': 622043424,
#   'full_name': 'jesselau76/srt-gpt-translator',
#   'url': 'https://github.com/jesselau76/srt-gpt-translator',
#   'clone_url': 'https://github.com/jesselau76/srt-gpt-translator.git',
#   'watchers_count': 83,
#   'stargazers_count': 83,
#   'language': 'Python',
#   'forks': 13,
#   'created_at': '2023-04-01T00:54:38Z',
#   'updated_at': '2023-06-16T06:42:17Z',
#   'pushed_at': '2023-04-05T05:34:19Z',
#   'description': 'Subtitle translator',
#   'languages_url': 'https://api.github.com/repos/jesselau76/srt-gpt-translator/languages',
#   'open_issues_count': 3,
#   'topics': ['gpt', 'srt', 'subtitle', 'translator'],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 622372991,
#   'full_name': 'burakorkmez/leetcode-clone-youtube',
#   'url': 'https://github.com/burakorkmez/leetcode-clone-youtube',
#   'clone_url': 'https://github.com/burakorkmez/leetcode-clone-youtube.git',
#   'watchers_count': 80,
#   'stargazers_count': 80,
#   'language': 'TypeScript',
#   'forks': 35,
#   'created_at': '2023-04-01T23:02:40Z',
#   'updated_at': '2023-06-16T02:49:57Z',
#   'pushed_at': '2023-05-30T07:11:41Z',
#   'description': None,
#   'languages_url': 'https://api.github.com/repos/burakorkmez/leetcode-clone-youtube/languages',
#   'open_issues_count': 1,
#   'topics': [],
#   'license': None},
#  {'id': 622101521,
#   'full_name': 'noir-lang/noir-starter',
#   'url': 'https://github.com/noir-lang/noir-starter',
#   'clone_url': 'https://github.com/noir-lang/noir-starter.git',
#   'watchers_count': 79,
#   'stargazers_count': 79,
#   'language': 'Solidity',
#   'forks': 8,
#   'created_at': '2023-04-01T05:53:00Z',
#   'updated_at': '2023-06-16T08:57:00Z',
#   'pushed_at': '2023-06-15T16:50:58Z',
#   'description': None,
#   'languages_url': 'https://api.github.com/repos/noir-lang/noir-starter/languages',
#   'open_issues_count': 4,
#   'topics': [],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 622053295,
#   'full_name': 'yebekhe/argo-pass',
#   'url': 'https://github.com/yebekhe/argo-pass',
#   'clone_url': 'https://github.com/yebekhe/argo-pass.git',
#   'watchers_count': 77,
#   'stargazers_count': 77,
#   'language': 'Shell',
#   'forks': 4684,
#   'created_at': '2023-04-01T01:48:07Z',
#   'updated_at': '2023-06-01T14:08:10Z',
#   'pushed_at': '2023-04-22T18:42:10Z',
#   'description': None,
#   'languages_url': 'https://api.github.com/repos/yebekhe/argo-pass/languages',
#   'open_issues_count': 2,
#   'topics': [],
#   'license': {'key': 'agpl-3.0',
#    'name': 'GNU Affero General Public License v3.0',
#    'spdx_id': 'AGPL-3.0',
#    'url': 'https://api.github.com/licenses/agpl-3.0',
#    'node_id': 'MDc6TGljZW5zZTE='}},
#  {'id': 622381744,
#   'full_name': 'vra/talkGPT4All',
#   'url': 'https://github.com/vra/talkGPT4All',
#   'clone_url': 'https://github.com/vra/talkGPT4All.git',
#   'watchers_count': 75,
#   'stargazers_count': 75,
#   'language': 'Python',
#   'forks': 9,
#   'created_at': '2023-04-01T23:54:00Z',
#   'updated_at': '2023-06-15T02:15:36Z',
#   'pushed_at': '2023-05-28T08:18:52Z',
#   'description': 'A voice chatbot based on GPT4All and talkGPT, running on your local pc!',
#   'languages_url': 'https://api.github.com/repos/vra/talkGPT4All/languages',
#   'open_issues_count': 2,
#   'topics': ['ai',
#    'chatbot',
#    'gpt4all',
#    'llama',
#    'llm',
#    'python',
#    'whisper-ai'],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 622112844,
#   'full_name': 'ra83205/google-bard-api',
#   'url': 'https://github.com/ra83205/google-bard-api',
#   'clone_url': 'https://github.com/ra83205/google-bard-api.git',
#   'watchers_count': 75,
#   'stargazers_count': 75,
#   'language': 'Python',
#   'forks': 26,
#   'created_at': '2023-04-01T06:41:07Z',
#   'updated_at': '2023-06-15T13:53:43Z',
#   'pushed_at': '2023-05-14T18:40:25Z',
#   'description': 'This project provides a FastAPI wrapper for interacting with Google Bard, a conversational AI by Google. It allows users to send messages to Google Bard and receive responses through a simple API.',
#   'languages_url': 'https://api.github.com/repos/ra83205/google-bard-api/languages',
#   'open_issues_count': 6,
#   'topics': ['ai-assistant',
#    'bard',
#    'bard-api',
#    'chat-gpt',
#    'chat-interface',
#    'chatbot-development',
#    'dialog-systems',
#    'fastapi',
#    'google-bard',
#    'machine-learning',
#    'natural-language-processing',
#    'python'],
#   'license': None},
#  {'id': 622218824,
#   'full_name': 'adityar224/FlutterMarkdownEditor',
#   'url': 'https://github.com/adityar224/FlutterMarkdownEditor',
#   'clone_url': 'https://github.com/adityar224/FlutterMarkdownEditor.git',
#   'watchers_count': 75,
#   'stargazers_count': 75,
#   'language': 'C++',
#   'forks': 10,
#   'created_at': '2023-04-01T13:25:43Z',
#   'updated_at': '2023-06-03T15:44:36Z',
#   'pushed_at': '2023-04-15T20:31:06Z',
#   'description': 'Markdown Editor app allows easy markdown file creation and editing. It opens ".md" files directly from explorer, provides text styling options, effortless link addition, Light and Dark Theme Modes, Multiple View Modes. Developed using Flutter, it\'s mainly intended for mobile devices as there are no standalone markdown editors presently available.',
#   'languages_url': 'https://api.github.com/repos/adityar224/FlutterMarkdownEditor/languages',
#   'open_issues_count': 1,
#   'topics': ['android',
#    'dart',
#    'flutter',
#    'flutter-apps',
#    'flutter-examples',
#    'markdown',
#    'markdown-editor',
#    'markdown-previewer',
#    'mobile-app'],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 622225243,
#   'full_name': 'muerrilla/stable-diffusion-NPW',
#   'url': 'https://github.com/muerrilla/stable-diffusion-NPW',
#   'clone_url': 'https://github.com/muerrilla/stable-diffusion-NPW.git',
#   'watchers_count': 70,
#   'stargazers_count': 70,
#   'language': 'Python',
#   'forks': 5,
#   'created_at': '2023-04-01T13:47:06Z',
#   'updated_at': '2023-06-15T21:29:58Z',
#   'pushed_at': '2023-06-02T13:48:42Z',
#   'description': 'Negative Prompt Weight: Extension for Stable Diffusion Web UI',
#   'languages_url': 'https://api.github.com/repos/muerrilla/stable-diffusion-NPW/languages',
#   'open_issues_count': 1,
#   'topics': [],
#   'license': {'key': 'unlicense',
#    'name': 'The Unlicense',
#    'spdx_id': 'Unlicense',
#    'url': 'https://api.github.com/licenses/unlicense',
#    'node_id': 'MDc6TGljZW5zZTE1'}},
#  {'id': 622048803,
#   'full_name': 'adamlui/chatgpt-apps',
#   'url': 'https://github.com/adamlui/chatgpt-apps',
#   'clone_url': 'https://github.com/adamlui/chatgpt-apps.git',
#   'watchers_count': 66,
#   'stargazers_count': 66,
#   'language': 'JavaScript',
#   'forks': 6,
#   'created_at': '2023-04-01T01:23:31Z',
#   'updated_at': '2023-06-16T00:06:31Z',
#   'pushed_at': '2023-06-15T21:51:22Z',
#   'description': '🤖 Apps that utilize the astounding power of ChatGPT or enhance its UX',
#   'languages_url': 'https://api.github.com/repos/adamlui/chatgpt-apps/languages',
#   'open_issues_count': 1,
#   'topics': ['ai',
#    'artificialintelligence',
#    'brave',
#    'brave-search',
#    'chat',
#    'chatbot',
#    'chatgpt',
#    'chatgpt3',
#    'chatgpt35-turbo',
#    'duckduckgo',
#    'gpt-3',
#    'gpt-4',
#    'gpt3',
#    'greasemonkey',
#    'javascript',
#    'machine-learning',
#    'ml',
#    'nlp',
#    'openai',
#    'userscript'],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 622132226,
#   'full_name': 'AndrewRadev/typewriter.vim',
#   'url': 'https://github.com/AndrewRadev/typewriter.vim',
#   'clone_url': 'https://github.com/AndrewRadev/typewriter.vim.git',
#   'watchers_count': 66,
#   'stargazers_count': 66,
#   'language': 'Vim Script',
#   'forks': 1,
#   'created_at': '2023-04-01T08:04:19Z',
#   'updated_at': '2023-05-30T09:49:21Z',
#   'pushed_at': '2023-04-16T08:15:12Z',
#   'description': 'Make cool typewriter sounds in insert mode',
#   'languages_url': 'https://api.github.com/repos/AndrewRadev/typewriter.vim/languages',
#   'open_issues_count': 0,
#   'topics': ['sound', 'typewriter', 'vim'],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 622059187,
#   'full_name': 'NateBaldwinDesign/proportio',
#   'url': 'https://github.com/NateBaldwinDesign/proportio',
#   'clone_url': 'https://github.com/NateBaldwinDesign/proportio.git',
#   'watchers_count': 65,
#   'stargazers_count': 65,
#   'language': 'JavaScript',
#   'forks': 2,
#   'created_at': '2023-04-01T02:20:46Z',
#   'updated_at': '2023-06-16T07:14:10Z',
#   'pushed_at': '2023-05-19T17:53:46Z',
#   'description': 'Tool for creating proportional scales for typography, iconography, spacing, and components in design systems.',
#   'languages_url': 'https://api.github.com/repos/NateBaldwinDesign/proportio/languages',
#   'open_issues_count': 2,
#   'topics': [],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 622265180,
#   'full_name': 'kangkaisen/olap-performance',
#   'url': 'https://github.com/kangkaisen/olap-performance',
#   'clone_url': 'https://github.com/kangkaisen/olap-performance.git',
#   'watchers_count': 65,
#   'stargazers_count': 65,
#   'language': 'TypeScript',
#   'forks': 5,
#   'created_at': '2023-04-01T15:49:50Z',
#   'updated_at': '2023-06-13T06:00:38Z',
#   'pushed_at': '2023-06-12T04:39:45Z',
#   'description': 'OLAP Database Performance Tuning Guide',
#   'languages_url': 'https://api.github.com/repos/kangkaisen/olap-performance/languages',
#   'open_issues_count': 0,
#   'topics': ['cpp', 'database', 'olap', 'performance', 'query', 'simd'],
#   'license': None},
#  {'id': 622059122,
#   'full_name': 'mscheong01/krotoDC',
#   'url': 'https://github.com/mscheong01/krotoDC',
#   'clone_url': 'https://github.com/mscheong01/krotoDC.git',
#   'watchers_count': 64,
#   'stargazers_count': 64,
#   'language': 'Kotlin',
#   'forks': 4,
#   'created_at': '2023-04-01T02:20:25Z',
#   'updated_at': '2023-06-14T11:49:26Z',
#   'pushed_at': '2023-06-14T14:43:50Z',
#   'description': 'Protobuf Kotlin Dataclass, Converter & Custom Kotlin Coroutine gRPC Generator',
#   'languages_url': 'https://api.github.com/repos/mscheong01/krotoDC/languages',
#   'open_issues_count': 5,
#   'topics': ['grpc-java',
#    'grpc-kotlin',
#    'kotlin',
#    'kotlinpoet',
#    'protobuf',
#    'protobuf-java'],
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='}},
#  {'id': 622146566,
#   'full_name': 'zkp2p/zk-p2p',
#   'url': 'https://github.com/zkp2p/zk-p2p',
#   'clone_url': 'https://github.com/zkp2p/zk-p2p.git',
#   'watchers_count': 63,
#   'stargazers_count': 63,
#   'language': 'TypeScript',
#   'forks': 5,
#   'created_at': '2023-04-01T09:01:54Z',
#   'updated_at': '2023-06-05T23:13:04Z',
#   'pushed_at': '2023-06-16T06:28:13Z',
#   'description': None,
#   'languages_url': 'https://api.github.com/repos/zkp2p/zk-p2p/languages',
#   'open_issues_count': 2,
#   'topics': [],
#   'license': None},
#  {'id': 622281703,
#   'full_name': 'herobrine19/openai-billing',
#   'url': 'https://github.com/herobrine19/openai-billing',
#   'clone_url': 'https://github.com/herobrine19/openai-billing.git',
#   'watchers_count': 61,
#   'stargazers_count': 61,
#   'language': 'HTML',
#   'forks': 31,
#   'created_at': '2023-04-01T16:43:51Z',
#   'updated_at': '2023-06-16T04:23:28Z',
#   'pushed_at': '2023-04-06T09:30:42Z',
#   'description': '使用 apikey 查询 openai apikey 余额',
#   'languages_url': 'https://api.github.com/repos/herobrine19/openai-billing/languages',
#   'open_issues_count': 4,
#   'topics': [],
#   'license': None},
#  {'id': 622035823,
#   'full_name': 'nostr-jp/awesome-nostr-japan',
#   'url': 'https://github.com/nostr-jp/awesome-nostr-japan',
#   'clone_url': 'https://github.com/nostr-jp/awesome-nostr-japan.git',
#   'watchers_count': 60,
#   'stargazers_count': 60,
#   'language': None,
#   'forks': 6,
#   'created_at': '2023-04-01T00:14:40Z',
#   'updated_at': '2023-06-05T16:10:01Z',
#   'pushed_at': '2023-05-06T05:21:09Z',
#   'description': 'Awesome nostr in Japan. Software, Web service, Clients, Bots created by Japanese.',
#   'languages_url': 'https://api.github.com/repos/nostr-jp/awesome-nostr-japan/languages',
#   'open_issues_count': 0,
#   'topics': ['japanese', 'nostr'],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 622085088,
#   'full_name': 'sciencecorp/buildabot',
#   'url': 'https://github.com/sciencecorp/buildabot',
#   'clone_url': 'https://github.com/sciencecorp/buildabot.git',
#   'watchers_count': 58,
#   'stargazers_count': 58,
#   'language': 'TypeScript',
#   'forks': 4,
#   'created_at': '2023-04-01T04:31:42Z',
#   'updated_at': '2023-06-04T01:54:00Z',
#   'pushed_at': '2023-04-11T07:12:35Z',
#   'description': 'A production-grade framework for building AI agents.',
# ...
#   'url': 'https://github.com/devvsakib/call-police-game',
#   'clone_url': 'https://github.com/devvsakib/call-police-game.git',
#   'watchers_count': 3,
#   'stargazers_count': 3,
#   'language': 'Python',
#   'forks': 5,
#   'created_at': '2023-04-01T07:02:37Z',
#   'updated_at': '2023-04-05T07:23:57Z',
#   'pushed_at': '2023-04-01T09:24:29Z',
#   'description': 'Open Source game. Contribute and enhance your skill',
#   'languages_url': 'https://api.github.com/repos/devvsakib/call-police-game/languages',
#   'open_issues_count': 3,
#   'topics': ['game',
#    'game-development',
#    'open-source',
#    'pygame',
#    'pygame-2d-engine',
#    'pygame-library',
#    'python'],
#   'license': None},
#  {'id': 622274728,
#   'full_name': 'Kashyab19/hbc-2023-axelar',
#   'url': 'https://github.com/Kashyab19/hbc-2023-axelar',
#   'clone_url': 'https://github.com/Kashyab19/hbc-2023-axelar.git',
#   'watchers_count': 3,
#   'stargazers_count': 3,
#   'language': 'JavaScript',
#   'forks': 4,
#   'created_at': '2023-04-01T16:21:05Z',
#   'updated_at': '2023-05-16T06:58:27Z',
#   'pushed_at': '2023-04-25T13:36:22Z',
#   'description': None,
#   'languages_url': 'https://api.github.com/repos/Kashyab19/hbc-2023-axelar/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': None},
#  {'id': 622062970,
#   'full_name': 'PromptProgrammingLanguage/prompt',
#   'url': 'https://github.com/PromptProgrammingLanguage/prompt',
#   'clone_url': 'https://github.com/PromptProgrammingLanguage/prompt.git',
#   'watchers_count': 3,
#   'stargazers_count': 3,
#   'language': 'Rust',
#   'forks': 0,
#   'created_at': '2023-04-01T02:39:47Z',
#   'updated_at': '2023-05-16T13:36:14Z',
#   'pushed_at': '2023-04-13T01:27:23Z',
#   'description': 'The prompt programming language',
#   'languages_url': 'https://api.github.com/repos/PromptProgrammingLanguage/prompt/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 622281321,
#   'full_name': 'HosseineShams/Spotify-Downloader',
#   'url': 'https://github.com/HosseineShams/Spotify-Downloader',
#   'clone_url': 'https://github.com/HosseineShams/Spotify-Downloader.git',
#   'watchers_count': 3,
#   'stargazers_count': 3,
#   'language': None,
#   'forks': 0,
#   'created_at': '2023-04-01T16:42:40Z',
#   'updated_at': '2023-04-21T10:32:58Z',
#   'pushed_at': '2023-04-01T16:42:41Z',
#   'description': 'A telegram bot to download Spotify songs',
#   'languages_url': 'https://api.github.com/repos/HosseineShams/Spotify-Downloader/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': None},
#  {'id': 622312505,
#   'full_name': 'mikejongbloet/obsidian-get-stock-information',
#   'url': 'https://github.com/mikejongbloet/obsidian-get-stock-information',
#   'clone_url': 'https://github.com/mikejongbloet/obsidian-get-stock-information.git',
#   'watchers_count': 3,
#   'stargazers_count': 3,
#   'language': 'TypeScript',
#   'forks': 0,
#   'created_at': '2023-04-01T18:30:06Z',
#   'updated_at': '2023-04-23T16:31:18Z',
#   'pushed_at': '2023-04-05T20:47:19Z',
#   'description': None,
#   'languages_url': 'https://api.github.com/repos/mikejongbloet/obsidian-get-stock-information/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 622140296,
#   'full_name': 'akashthakurr/Python-practice-day2',
#   'url': 'https://github.com/akashthakurr/Python-practice-day2',
#   'clone_url': 'https://github.com/akashthakurr/Python-practice-day2.git',
#   'watchers_count': 3,
#   'stargazers_count': 3,
#   'language': 'Python',
#   'forks': 0,
#   'created_at': '2023-04-01T08:37:07Z',
#   'updated_at': '2023-04-27T09:57:48Z',
#   'pushed_at': '2023-04-07T09:00:24Z',
#   'description': 'Hii, I am doing a coding challenge this is the list of program which I practiced in day 2.',
#   'languages_url': 'https://api.github.com/repos/akashthakurr/Python-practice-day2/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': None},
#  {'id': 622273417,
#   'full_name': 'NicDeveloper7/DecomposicaoDecimal',
#   'url': 'https://github.com/NicDeveloper7/DecomposicaoDecimal',
#   'clone_url': 'https://github.com/NicDeveloper7/DecomposicaoDecimal.git',
#   'watchers_count': 3,
#   'stargazers_count': 3,
#   'language': 'C#',
#   'forks': 0,
#   'created_at': '2023-04-01T16:16:30Z',
#   'updated_at': '2023-05-06T00:25:52Z',
#   'pushed_at': '2023-04-02T16:12:05Z',
#   'description': 'Programa que recebe um número inteiro informado pelo usuário. Realiza a decomposição decimal em unidades, dezenas e centenas.',
#   'languages_url': 'https://api.github.com/repos/NicDeveloper7/DecomposicaoDecimal/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': None},
#  {'id': 622141853,
#   'full_name': 'yuyushui66/ScheduleManagement',
#   'url': 'https://github.com/yuyushui66/ScheduleManagement',
#   'clone_url': 'https://github.com/yuyushui66/ScheduleManagement.git',
#   'watchers_count': 3,
#   'stargazers_count': 3,
#   'language': 'HTML',
#   'forks': 0,
#   'created_at': '2023-04-01T08:43:37Z',
#   'updated_at': '2023-04-15T13:41:35Z',
#   'pushed_at': '2023-05-07T06:36:19Z',
#   'description': '软件工程大作业-东北大学',
#   'languages_url': 'https://api.github.com/repos/yuyushui66/ScheduleManagement/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': None},
#  {'id': 622135292,
#   'full_name': 'cms-dpoa/cat-hackathon',
#   'url': 'https://github.com/cms-dpoa/cat-hackathon',
#   'clone_url': 'https://github.com/cms-dpoa/cat-hackathon.git',
#   'watchers_count': 3,
#   'stargazers_count': 3,
#   'language': 'Python',
#   'forks': 2,
#   'created_at': '2023-04-01T08:16:16Z',
#   'updated_at': '2023-05-03T04:32:26Z',
#   'pushed_at': '2023-05-08T01:29:39Z',
#   'description': 'Working material for DPOA in Common Analysis Tools (CAT) hackathon (April 2023)',
#   'languages_url': 'https://api.github.com/repos/cms-dpoa/cat-hackathon/languages',
#   'open_issues_count': 4,
#   'topics': [],
#   'license': None},
#  {'id': 622064562,
#   'full_name': 'futzu/umzz',
#   'url': 'https://github.com/futzu/umzz',
#   'clone_url': 'https://github.com/futzu/umzz.git',
#   'watchers_count': 3,
#   'stargazers_count': 3,
#   'language': 'Python',
#   'forks': 1,
#   'created_at': '2023-04-01T02:48:01Z',
#   'updated_at': '2023-04-20T20:16:15Z',
#   'pushed_at': '2023-04-14T07:27:30Z',
#   'description': 'SCTE-35 Injection for Adaptive Bitrate HLS',
#   'languages_url': 'https://api.github.com/repos/futzu/umzz/languages',
#   'open_issues_count': 3,
#   'topics': ['ad-break',
#    'adrian-of-doom',
#    'hls',
#    'hls-live-streaming',
#    'hls-stream',
#    'mpegts',
#    'pypy3',
#    'python3',
#    'scte-35',
#    'scte35',
#    'sexy',
#    'threefive',
#    'ultra-mega-zoom-zoom',
#    'umzz'],
#   'license': {'key': 'gpl-3.0',
#    'name': 'GNU General Public License v3.0',
#    'spdx_id': 'GPL-3.0',
#    'url': 'https://api.github.com/licenses/gpl-3.0',
#    'node_id': 'MDc6TGljZW5zZTk='}},
#  {'id': 622322977,
#   'full_name': 'dojo-recife/dojo-recife-site-api',
#   'url': 'https://github.com/dojo-recife/dojo-recife-site-api',
#   'clone_url': 'https://github.com/dojo-recife/dojo-recife-site-api.git',
#   'watchers_count': 3,
#   'stargazers_count': 3,
#   'language': 'Python',
#   'forks': 3,
#   'created_at': '2023-04-01T19:08:46Z',
#   'updated_at': '2023-04-28T02:07:47Z',
#   'pushed_at': '2023-05-10T00:43:29Z',
#   'description': 'API do site em desevolvimento do dojo recife',
#   'languages_url': 'https://api.github.com/repos/dojo-recife/dojo-recife-site-api/languages',
#   'open_issues_count': 10,
#   'topics': [],
#   'license': None},
#  {'id': 622317931,
#   'full_name': 'EimaMei/Silicon',
#   'url': 'https://github.com/EimaMei/Silicon',
#   'clone_url': 'https://github.com/EimaMei/Silicon.git',
#   'watchers_count': 3,
#   'stargazers_count': 3,
#   'language': 'C',
#   'forks': 1,
#   'created_at': '2023-04-01T18:49:43Z',
#   'updated_at': '2023-04-11T15:55:02Z',
#   'pushed_at': '2023-05-01T17:10:12Z',
#   'description': "An alternative, pure C-focused wrapper to Apple's Cocoa API for OS X app development and basic iOS programming. Requires little to no Objective-C knowledge to use.",
#   'languages_url': 'https://api.github.com/repos/EimaMei/Silicon/languages',
#   'open_issues_count': 0,
#   'topics': ['api',
#    'appkit',
#    'c',
#    'cocoa',
#    'ios',
#    'iphone',
#    'macos',
#    'objective-c'],
#   'license': {'key': 'zlib',
#    'name': 'zlib License',
#    'spdx_id': 'Zlib',
#    'url': 'https://api.github.com/licenses/zlib',
#    'node_id': 'MDc6TGljZW5zZTI3'}},
#  {'id': 622157868,
#   'full_name': 'JacintaNgwu/TDD',
#   'url': 'https://github.com/JacintaNgwu/TDD',
#   'clone_url': 'https://github.com/JacintaNgwu/TDD.git',
#   'watchers_count': 3,
#   'stargazers_count': 3,
#   'language': 'Ruby',
#   'forks': 0,
#   'created_at': '2023-04-01T09:43:56Z',
#   'updated_at': '2023-04-21T20:12:07Z',
#   'pushed_at': '2023-04-01T09:58:12Z',
#   'description': 'The project is about testing a few methods using RSpec. The methods are: factorial, reverse and fizzbuzz.',
#   'languages_url': 'https://api.github.com/repos/JacintaNgwu/TDD/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 622091890,
#   'full_name': 'tushar2242/documentClustering',
#   'url': 'https://github.com/tushar2242/documentClustering',
#   'clone_url': 'https://github.com/tushar2242/documentClustering.git',
#   'watchers_count': 3,
#   'stargazers_count': 3,
#   'language': 'Jupyter Notebook',
#   'forks': 0,
#   'created_at': '2023-04-01T05:05:19Z',
#   'updated_at': '2023-06-05T07:44:05Z',
#   'pushed_at': '2023-04-01T05:17:39Z',
#   'description': None,
#   'languages_url': 'https://api.github.com/repos/tushar2242/documentClustering/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': None},
#  {'id': 622251076,
#   'full_name': 'vyual/trunner',
#   'url': 'https://github.com/vyual/trunner',
#   'clone_url': 'https://github.com/vyual/trunner.git',
#   'watchers_count': 3,
#   'stargazers_count': 3,
#   'language': 'C++',
#   'forks': 0,
#   'created_at': '2023-04-01T15:06:38Z',
#   'updated_at': '2023-04-17T05:55:57Z',
#   'pushed_at': '2023-06-05T09:01:04Z',
#   'description': None,
#   'languages_url': 'https://api.github.com/repos/vyual/trunner/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': {'key': 'gpl-3.0',
#    'name': 'GNU General Public License v3.0',
#    'spdx_id': 'GPL-3.0',
#    'url': 'https://api.github.com/licenses/gpl-3.0',
#    'node_id': 'MDc6TGljZW5zZTk='}},
#  {'id': 622118860,
#   'full_name': 'rico233333333/RUST-Learn',
#   'url': 'https://github.com/rico233333333/RUST-Learn',
#   'clone_url': 'https://github.com/rico233333333/RUST-Learn.git',
#   'watchers_count': 3,
#   'stargazers_count': 3,
#   'language': 'Makefile',
#   'forks': 0,
#   'created_at': '2023-04-01T07:06:43Z',
#   'updated_at': '2023-06-15T05:59:16Z',
#   'pushed_at': '2023-06-13T02:42:15Z',
#   'description': 'RUST练习，按照RUST语言圣经走滴',
#   'languages_url': 'https://api.github.com/repos/rico233333333/RUST-Learn/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': None},
#  {'id': 622110417,
#   'full_name': 'MannyFay/Start-to-Code',
#   'url': 'https://github.com/MannyFay/Start-to-Code',
#   'clone_url': 'https://github.com/MannyFay/Start-to-Code.git',
#   'watchers_count': 3,
#   'stargazers_count': 3,
#   'language': 'CSS',
#   'forks': 0,
#   'created_at': '2023-04-01T06:31:07Z',
#   'updated_at': '2023-06-12T07:15:16Z',
#   'pushed_at': '2023-04-23T07:48:48Z',
#   'description': 'Ready made environments to start with coding.',
#   'languages_url': 'https://api.github.com/repos/MannyFay/Start-to-Code/languages',
#   'open_issues_count': 0,
#   'topics': ['beginner-friendly',
#    'bootstrap',
#    'coding',
#    'css',
#    'html',
#    'javascript',
#    'php',
#    'tailwindcss'],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 622287652,
#   'full_name': 'MoAasim/Practice-and-examples',
#   'url': 'https://github.com/MoAasim/Practice-and-examples',
#   'clone_url': 'https://github.com/MoAasim/Practice-and-examples.git',
#   'watchers_count': 2,
#   'stargazers_count': 2,
#   'language': 'Python',
#   'forks': 0,
#   'created_at': '2023-04-01T17:03:49Z',
#   'updated_at': '2023-04-09T10:05:34Z',
#   'pushed_at': '2023-04-09T09:48:11Z',
#   'description': 'To have some Python example codes',
#   'languages_url': 'https://api.github.com/repos/MoAasim/Practice-and-examples/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': None},
#  {'id': 622201697,
#   'full_name': 'Lenonkoech/Simple-ATM-Simulator',
#   'url': 'https://github.com/Lenonkoech/Simple-ATM-Simulator',
#   'clone_url': 'https://github.com/Lenonkoech/Simple-ATM-Simulator.git',
#   'watchers_count': 2,
#   'stargazers_count': 2,
#   'language': 'C',
#   'forks': 0,
#   'created_at': '2023-04-01T12:27:24Z',
#   'updated_at': '2023-04-01T16:55:50Z',
#   'pushed_at': '2023-04-01T12:31:09Z',
#   'description': None,
#   'languages_url': 'https://api.github.com/repos/Lenonkoech/Simple-ATM-Simulator/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': None},
#  {'id': 622211715,
#   'full_name': 'CrystallineButterfly/speechgpt-refactor',
#   'url': 'https://github.com/CrystallineButterfly/speechgpt-refactor',
#   'clone_url': 'https://github.com/CrystallineButterfly/speechgpt-refactor.git',
#   'watchers_count': 2,
#   'stargazers_count': 2,
#   'language': 'TypeScript',
#   'forks': 0,
#   'created_at': '2023-04-01T13:02:16Z',
#   'updated_at': '2023-04-01T13:19:37Z',
#   'pushed_at': '2023-04-01T13:05:11Z',
#   'description': None,
#   'languages_url': 'https://api.github.com/repos/CrystallineButterfly/speechgpt-refactor/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 622295194,
#   'full_name': 'Mattezucca1/Auto-writer',
#   'url': 'https://github.com/Mattezucca1/Auto-writer',
#   'clone_url': 'https://github.com/Mattezucca1/Auto-writer.git',
#   'watchers_count': 2,
#   'stargazers_count': 2,
#   'language': 'Python',
#   'forks': 0,
#   'created_at': '2023-04-01T17:29:06Z',
#   'updated_at': '2023-04-01T19:41:12Z',
#   'pushed_at': '2023-04-02T09:09:06Z',
#   'description': 'Un auto writer per tutte le applicazioni',
#   'languages_url': 'https://api.github.com/repos/Mattezucca1/Auto-writer/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 622234001,
#   'full_name': 'RHK-MICROVERSE/RHK-MICROVERSE',
#   'url': 'https://github.com/RHK-MICROVERSE/RHK-MICROVERSE',
#   'clone_url': 'https://github.com/RHK-MICROVERSE/RHK-MICROVERSE.git',
#   'watchers_count': 2,
#   'stargazers_count': 2,
#   'language': None,
#   'forks': 0,
#   'created_at': '2023-04-01T14:14:59Z',
#   'updated_at': '2023-04-03T22:57:41Z',
#   'pushed_at': '2023-04-03T15:33:56Z',
#   'description': None,
#   'languages_url': 'https://api.github.com/repos/RHK-MICROVERSE/RHK-MICROVERSE/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': None},
#  {'id': 622097359,
#   'full_name': 'yuys13/skk-develop.nvim',
#   'url': 'https://github.com/yuys13/skk-develop.nvim',
#   'clone_url': 'https://github.com/yuys13/skk-develop.nvim.git',
#   'watchers_count': 2,
#   'stargazers_count': 2,
#   'language': 'Lua',
#   'forks': 0,
#   'created_at': '2023-04-01T05:33:06Z',
#   'updated_at': '2023-04-05T15:07:34Z',
#   'pushed_at': '2023-04-11T11:21:37Z',
#   'description': 'skk-develop.nvim provides skk-get for neovim',
#   'languages_url': 'https://api.github.com/repos/yuys13/skk-develop.nvim/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  ...]

# %%
df = pd.DataFrame.from_dict(repositories)
df.to_csv('C:\\csv-data-collect\\2023-04.csv')

# %%
df.shape
# Out:
# (29000, 16)

# %%
import requests as req
import time
# Replace with your personal access token
access_token = "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"

# API endpoint for retrieving repository information
url = "https://api.github.com/search/repositories"

# Construct the headers with the access token
headers = {
    "Authorization": f"Bearer {access_token}",
    "Accept": "application/vnd.github.v3+json"  # Specify the API version
}

def getDay(day):
    if day < 10:
        return str(f'0{day}')
    else:
        return day
repositories = []
page = 1
day = 1
while True:
    print(day)
    while True:
        params = {
            "q": f"created:2023-01-{getDay(day)}",
            "sort": "stars",
            "order": "desc",
            "per_page": 100,
            "page": page
        }
        response = req.get(url, headers=headers, params=params)
        if response.status_code == 200:
            data = response.json()['items']
            repositories.append([{
                'id':repo['id'],
                'full_name':repo['full_name'],
                'url':repo['html_url'],
                'clone_url':repo['clone_url'],
                'watchers_count':repo['watchers_count'],
                'stargazers_count':repo['stargazers_count'],
                'language':repo['language'],
                'forks':repo['forks'],
                'created_at':repo['created_at'],
                'updated_at':repo['updated_at'],
                'pushed_at':repo['pushed_at'],
                'description':repo['description'],
                'languages_url':repo['languages_url'],
                'open_issues_count':repo['open_issues_count'],

                } for repo in data])
            if "next" in response.links:
                page += 1
            else:
                print(page)
                break
        else:
            print(f"Error: {response.status_code} - {response.text}")
        time.sleep(1)
    if page == 10:
        page = 1
        day += 1
    if day > 2:
        break
    time.sleep(1)
repositories

# %%
access_token = "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"

url = "https://api.github.com/search/repositories"

headers = {
    "Authorization": f"Bearer {access_token}",
    "Accept": "application/vnd.github.v3+json"  # Specify the API version
}

response = req.get(url, headers=headers, params=params)

start_date = datetime.date(2023, 1, 1)
end_date = datetime.date(2023, 5, 31)
delta = datetime.timedelta(days=1)

# Construct the headers with the access token
headers = {
    "Authorization": f"Bearer {access_token}",
    "Accept": "application/vnd.github.v3+json"  # Specify the API version
}
repositories = []
page = 1
while True:
    if start_date == datetime.date(2023, 5, 31):
        break
    while True:
        params = {
            "q": f"created:{start_date}",
            "sort": "stars",
            "order": "desc",
            "per_page": 100,
            "page": page
        }
        response = req.get(url, headers=headers, params=params)
        if response.status_code == 200:
            data = response.json()['items']
            repositories.extend([{
                'id':repo['id'],
                'full_name':repo['full_name'],
                'url':repo['html_url'],
                'clone_url':repo['clone_url'],
                'watchers_count':repo['watchers_count'],
                'stargazers_count':repo['stargazers_count'],
                'language':repo['language'],
                'forks':repo['forks'],
                'created_at':repo['created_at'],
                'updated_at':repo['updated_at'],
                'pushed_at':repo['pushed_at'],
                'description':repo['description'],
                'languages_url':repo['languages_url'],
                'open_issues_count':repo['open_issues_count'],
                'topics':repo['topics'],
                'license':repo['license']
                } for repo in data])
            if "next" in response.links:
                page += 1
            else:
                print(page)
                break
        else:
            print(f"Error: {response.status_code} - {response.text}")
        time.sleep(1)
    if page == 10:
        page = 1
        start_date += delta
    time.sleep(1)
repositories
# Out:
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# [{'id': 584145946,
#   'full_name': 'sumn2u/learn-javascript',
#   'url': 'https://github.com/sumn2u/learn-javascript',
#   'clone_url': 'https://github.com/sumn2u/learn-javascript.git',
#   'watchers_count': 619,
#   'stargazers_count': 619,
#   'language': 'HTML',
#   'forks': 29,
#   'created_at': '2023-01-01T15:16:26Z',
#   'updated_at': '2023-06-16T03:16:58Z',
#   'pushed_at': '2023-06-08T01:17:48Z',
#   'description': 'A book that teaches JavaScript',
#   'languages_url': 'https://api.github.com/repos/sumn2u/learn-javascript/languages',
#   'open_issues_count': 1,
#   'topics': ['beginner',
#    'beginner-friendly',
#    'book',
#    'collaborate',
#    'exercises',
#    'github',
#    'javascript',
#    'js',
#    'learn-javascript',
#    'learn-to-code',
#    'learning',
#    'open-source',
#    'programming',
#    'programming-language',
#    'student-vscode'],
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='}},
#  {'id': 584165139,
#   'full_name': 'bianchenglequ/NetCodeTop',
#   'url': 'https://github.com/bianchenglequ/NetCodeTop',
#   'clone_url': 'https://github.com/bianchenglequ/NetCodeTop.git',
#   'watchers_count': 567,
#   'stargazers_count': 567,
#   'language': None,
#   'forks': 106,
#   'created_at': '2023-01-01T16:52:06Z',
#   'updated_at': '2023-06-16T04:21:24Z',
#   'pushed_at': '2023-06-04T17:37:55Z',
#   'description': '收集GitHub上有关.Net、.NetCore有趣、有用、热门的开源项目。',
#   'languages_url': 'https://api.github.com/repos/bianchenglequ/NetCodeTop/languages',
#   'open_issues_count': 1,
#   'topics': ['csharp', 'dotnet', 'net', 'netcore'],
#   'license': None},
#  {'id': 584189373,
#   'full_name': 'rupali-codes/LinksHub',
#   'url': 'https://github.com/rupali-codes/LinksHub',
#   'clone_url': 'https://github.com/rupali-codes/LinksHub.git',
#   'watchers_count': 343,
#   'stargazers_count': 343,
#   'language': 'TypeScript',
#   'forks': 269,
#   'created_at': '2023-01-01T18:55:44Z',
#   'updated_at': '2023-06-16T09:45:30Z',
#   'pushed_at': '2023-06-16T08:38:14Z',
#   'description': 'LinksHub aims to provide developers with access to a wide range of free resources and tools that they can use in their work. These resources include links to free software, libraries, frameworks, and other tools that can be used to build and deploy applications and websites.',
#   'languages_url': 'https://api.github.com/repos/rupali-codes/LinksHub/languages',
#   'open_issues_count': 85,
#   'topics': ['beginner-friendly',
#    'developers',
#    'links',
#    'nextjs',
#    'open-source',
#    'resources',
#    'tailwindcss',
#    'typescript'],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 584105200,
#   'full_name': 'LondheShubham153/90DaysOfDevOps',
#   'url': 'https://github.com/LondheShubham153/90DaysOfDevOps',
#   'clone_url': 'https://github.com/LondheShubham153/90DaysOfDevOps.git',
#   'watchers_count': 336,
#   'stargazers_count': 336,
#   'language': 'Python',
#   'forks': 2171,
#   'created_at': '2023-01-01T11:41:21Z',
#   'updated_at': '2023-06-13T09:47:39Z',
#   'pushed_at': '2023-06-13T22:14:45Z',
#   'description': 'This repository is a Challenge for the DevOps Community to get stronger in DevOps.  This challenge starts on the 1st January 2023 and in the next 90 Days we promise ourselves to become better at DevOps.  The reason for making this Public is so that others can learn from the community and help each other grow.',
#   'languages_url': 'https://api.github.com/repos/LondheShubham153/90DaysOfDevOps/languages',
#   'open_issues_count': 54,
#   'topics': ['devops',
#    'devops-tools',
#    'docker',
#    'grafana',
#    'jenkins',
#    'kubernetes',
#    'linux',
#    'prometheus',
#    'python',
#    'terraform'],
#   'license': {'key': 'other',
#    'name': 'Other',
#    'spdx_id': 'NOASSERTION',
#    'url': None,
#    'node_id': 'MDc6TGljZW5zZTA='}},
#  {'id': 584131216,
#   'full_name': 'jahidulislamzim/JavaScriptCodingChallenges',
#   'url': 'https://github.com/jahidulislamzim/JavaScriptCodingChallenges',
#   'clone_url': 'https://github.com/jahidulislamzim/JavaScriptCodingChallenges.git',
#   'watchers_count': 221,
#   'stargazers_count': 221,
#   'language': None,
#   'forks': 40,
#   'created_at': '2023-01-01T14:04:36Z',
#   'updated_at': '2023-05-28T14:24:58Z',
#   'pushed_at': '2023-01-24T05:22:17Z',
#   'description': "Hello JavaScript code newbie! In this repository I'm proposing you a series of coding challenges that will help you practice the basic language constructs and algorithms.",
#   'languages_url': 'https://api.github.com/repos/jahidulislamzim/JavaScriptCodingChallenges/languages',
#   'open_issues_count': 0,
#   'topics': ['coding',
#    'coding-challenge',
#    'coding-challenges',
#    'coding-test',
#    'javascript',
#    'javascript-es6',
#    'js',
#    'js-problem-solving',
#    'problem-solving',
#    'problems',
#    'problemsolving',
#    'programming'],
#   'license': None},
#  {'id': 584219588,
#   'full_name': '702573N/Obsidian-Tasks-Timeline',
#   'url': 'https://github.com/702573N/Obsidian-Tasks-Timeline',
#   'clone_url': 'https://github.com/702573N/Obsidian-Tasks-Timeline.git',
#   'watchers_count': 164,
#   'stargazers_count': 164,
#   'language': 'JavaScript',
#   'forks': 13,
#   'created_at': '2023-01-01T22:02:50Z',
#   'updated_at': '2023-06-14T20:36:49Z',
#   'pushed_at': '2023-06-02T07:24:32Z',
#   'description': 'A custom view build with Obsidian-Dataview to display tasks from Obsidian-Tasks and from your daily notes in a highly customisable timeline',
#   'languages_url': 'https://api.github.com/repos/702573N/Obsidian-Tasks-Timeline/languages',
#   'open_issues_count': 18,
#   'topics': ['dataview',
#    'obsidian-md',
#    'obsidian-plugin',
#    'tasks',
#    'timeline'],
#   'license': None},
#  {'id': 584022883,
#   'full_name': 'yacineMTB/scribepod',
#   'url': 'https://github.com/yacineMTB/scribepod',
#   'clone_url': 'https://github.com/yacineMTB/scribepod.git',
#   'watchers_count': 146,
#   'stargazers_count': 146,
#   'language': 'Jupyter Notebook',
#   'forks': 14,
#   'created_at': '2023-01-01T00:34:43Z',
#   'updated_at': '2023-06-14T06:17:11Z',
#   'pushed_at': '2023-03-04T22:08:55Z',
#   'description': 'Some of the scripts I use for scribepod @ https://scribepod.substack.com/, an automated AI podcast',
#   'languages_url': 'https://api.github.com/repos/yacineMTB/scribepod/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': None},
#  {'id': 584145750,
#   'full_name': 'jafarlihi/modreveal',
#   'url': 'https://github.com/jafarlihi/modreveal',
#   'clone_url': 'https://github.com/jafarlihi/modreveal.git',
#   'watchers_count': 130,
#   'stargazers_count': 130,
#   'language': 'C',
#   'forks': 11,
#   'created_at': '2023-01-01T15:15:27Z',
#   'updated_at': '2023-05-30T21:43:39Z',
#   'pushed_at': '2023-01-01T15:26:12Z',
#   'description': 'Utility to find hidden Linux kernel modules',
#   'languages_url': 'https://api.github.com/repos/jafarlihi/modreveal/languages',
#   'open_issues_count': 3,
#   'topics': ['blueteam',
#    'kernel-module',
#    'kernel-security',
#    'lkm',
#    'lkm-rootkit',
#    'security',
#    'security-audit',
#    'security-tools'],
#   'license': {'key': 'gpl-3.0',
#    'name': 'GNU General Public License v3.0',
#    'spdx_id': 'GPL-3.0',
#    'url': 'https://api.github.com/licenses/gpl-3.0',
#    'node_id': 'MDc6TGljZW5zZTk='}},
#  {'id': 584055812,
#   'full_name': 'leoantony72/twitter-backend',
#   'url': 'https://github.com/leoantony72/twitter-backend',
#   'clone_url': 'https://github.com/leoantony72/twitter-backend.git',
#   'watchers_count': 122,
#   'stargazers_count': 122,
#   'language': 'Go',
#   'forks': 12,
#   'created_at': '2023-01-01T05:51:44Z',
#   'updated_at': '2023-06-15T04:53:42Z',
#   'pushed_at': '2023-04-25T10:08:14Z',
#   'description': 'backend clone of Twitter with golang',
#   'languages_url': 'https://api.github.com/repos/leoantony72/twitter-backend/languages',
#   'open_issues_count': 1,
#   'topics': ['api',
#    'authentication',
#    'golang',
#    'jwt',
#    'jwt-authentication',
#    'postgresql',
#    'rabbitmq',
#    'redis',
#    'twitter'],
#   'license': None},
#  {'id': 584073425,
#   'full_name': 'sagoo-cloud/sagooiot',
#   'url': 'https://github.com/sagoo-cloud/sagooiot',
#   'clone_url': 'https://github.com/sagoo-cloud/sagooiot.git',
#   'watchers_count': 119,
#   'stargazers_count': 119,
#   'language': 'Go',
#   'forks': 33,
#   'created_at': '2023-01-01T08:06:18Z',
#   'updated_at': '2023-06-16T08:12:33Z',
#   'pushed_at': '2023-03-20T00:42:11Z',
#   'description': 'SagooIOT是一个基于golang开发的开源的企业级物联网基础开发平台。负责设备管理和协议数据管理，支持跨平台的物联网接入及管理方案，平台实现了物联网开发相关的基础功能，基于该功能可以快速的搭建起一整套的IOT相关的业务系统。旨在通过可复用的组件，减少开发工作，简化和加速物联网开发交付。适配多种接入协议(TCP,MQTT,UDP,CoAP,HTTP,GRPC,RPC等)',
#   'languages_url': 'https://api.github.com/repos/sagoo-cloud/sagooiot/languages',
#   'open_issues_count': 2,
#   'topics': ['goframe', 'gwt', 'iot', 'modbus', 'mqtt', 'vue-admin'],
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='}},
#  {'id': 584177219,
#   'full_name': 'acheong08/ChatGPT-lite',
#   'url': 'https://github.com/acheong08/ChatGPT-lite',
#   'clone_url': 'https://github.com/acheong08/ChatGPT-lite.git',
#   'watchers_count': 114,
#   'stargazers_count': 114,
#   'language': 'Python',
#   'forks': 19,
#   'created_at': '2023-01-01T17:52:42Z',
#   'updated_at': '2023-06-12T15:47:43Z',
#   'pushed_at': '2023-01-31T05:33:15Z',
#   'description': 'Lightweight ChatGPT without browser',
#   'languages_url': 'https://api.github.com/repos/acheong08/ChatGPT-lite/languages',
#   'open_issues_count': 13,
#   'topics': [],
#   'license': {'key': 'unlicense',
#    'name': 'The Unlicense',
#    'spdx_id': 'Unlicense',
#    'url': 'https://api.github.com/licenses/unlicense',
#    'node_id': 'MDc6TGljZW5zZTE1'}},
#  {'id': 584125242,
#   'full_name': 'yihong0618/2023',
#   'url': 'https://github.com/yihong0618/2023',
#   'clone_url': 'https://github.com/yihong0618/2023.git',
#   'watchers_count': 114,
#   'stargazers_count': 114,
#   'language': 'Python',
#   'forks': 16,
#   'created_at': '2023-01-01T13:34:44Z',
#   'updated_at': '2023-06-14T07:21:26Z',
#   'pushed_at': '2023-06-16T00:10:09Z',
#   'description': 'Another year',
#   'languages_url': 'https://api.github.com/repos/yihong0618/2023/languages',
#   'open_issues_count': 14,
#   'topics': [],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 584102226,
#   'full_name': 'kadirnar/torchyolo',
#   'url': 'https://github.com/kadirnar/torchyolo',
#   'clone_url': 'https://github.com/kadirnar/torchyolo.git',
#   'watchers_count': 112,
#   'stargazers_count': 112,
#   'language': 'Python',
#   'forks': 11,
#   'created_at': '2023-01-01T11:22:54Z',
#   'updated_at': '2023-06-16T09:55:36Z',
#   'pushed_at': '2023-02-10T11:48:12Z',
#   'description': 'PyTorch implementation of YOLOv5, YOLOv6, YOLOv7, YOLOv8, Sort, StrongSort, OcSort, ByteTrack, Norfair',
#   'languages_url': 'https://api.github.com/repos/kadirnar/torchyolo/languages',
#   'open_issues_count': 3,
#   'topics': ['bytetrack',
#    'norfair',
#    'ocsort',
#    'sort',
#    'strongsort',
#    'tracker',
#    'yolov5',
#    'yolov6',
#    'yolov7',
#    'yolov8',
#    'yolox'],
#   'license': {'key': 'gpl-3.0',
#    'name': 'GNU General Public License v3.0',
#    'spdx_id': 'GPL-3.0',
#    'url': 'https://api.github.com/licenses/gpl-3.0',
#    'node_id': 'MDc6TGljZW5zZTk='}},
#  {'id': 584215590,
#   'full_name': 'dilmerv/UnityChatGPT',
#   'url': 'https://github.com/dilmerv/UnityChatGPT',
#   'clone_url': 'https://github.com/dilmerv/UnityChatGPT.git',
#   'watchers_count': 105,
#   'stargazers_count': 105,
#   'language': 'C#',
#   'forks': 15,
#   'created_at': '2023-01-01T21:35:34Z',
#   'updated_at': '2023-06-12T20:20:18Z',
#   'pushed_at': '2023-04-25T17:55:41Z',
#   'description': 'Few examples with Chat GPT In Unity',
#   'languages_url': 'https://api.github.com/repos/dilmerv/UnityChatGPT/languages',
#   'open_issues_count': 1,
#   'topics': ['artificial-intelligence',
#    'chatgpt',
#    'chatgpt-api',
#    'text-to-speech',
#    'unity'],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 584022261,
#   'full_name': 'acantril/docker-fundamentals',
#   'url': 'https://github.com/acantril/docker-fundamentals',
#   'clone_url': 'https://github.com/acantril/docker-fundamentals.git',
#   'watchers_count': 103,
#   'stargazers_count': 103,
#   'language': 'JavaScript',
#   'forks': 120,
#   'created_at': '2023-01-01T00:27:58Z',
#   'updated_at': '2023-06-14T06:55:40Z',
#   'pushed_at': '2023-06-14T09:45:26Z',
#   'description': 'Course Assets for https://learn.cantrill.io/p/docker-fundamentals/',
#   'languages_url': 'https://api.github.com/repos/acantril/docker-fundamentals/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 584072360,
#   'full_name': 'feifeid47/Unity-Async-UIFrame',
#   'url': 'https://github.com/feifeid47/Unity-Async-UIFrame',
#   'clone_url': 'https://github.com/feifeid47/Unity-Async-UIFrame.git',
#   'watchers_count': 101,
#   'stargazers_count': 101,
#   'language': 'C#',
#   'forks': 12,
#   'created_at': '2023-01-01T07:58:30Z',
#   'updated_at': '2023-06-13T08:43:24Z',
#   'pushed_at': '2023-04-24T03:32:30Z',
#   'description': '简单易用的Unity异步UI框架。 足够轻量，无第三方依赖。 兼容多种资源管理系统（Addressable、YooAssets等）。支持使用HybridCLR热更新。 支持自动引用。 支持对UI面板的销毁控制，使内存优化更方便。 支持子UI，子子UI，子子子UI......',
#   'languages_url': 'https://api.github.com/repos/feifeid47/Unity-Async-UIFrame/languages',
#   'open_issues_count': 1,
#   'topics': ['ugui', 'uiframe', 'uiframework', 'unity', 'unity3d'],
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='}},
#  {'id': 584034634,
#   'full_name': 'TimMikeladze/gist-database',
#   'url': 'https://github.com/TimMikeladze/gist-database',
#   'clone_url': 'https://github.com/TimMikeladze/gist-database.git',
#   'watchers_count': 90,
#   'stargazers_count': 90,
#   'language': 'TypeScript',
#   'forks': 0,
#   'created_at': '2023-01-01T02:34:59Z',
#   'updated_at': '2023-06-08T08:15:44Z',
#   'pushed_at': '2023-06-03T03:35:29Z',
#   'description': '✨ Transform gist into your personal key/value datastore. 💡Pair this with Next.js static sites and incremental static regeneration. Built with TypeScript.',
#   'languages_url': 'https://api.github.com/repos/TimMikeladze/gist-database/languages',
#   'open_issues_count': 4,
#   'topics': ['datastore',
#    'gist',
#    'gist-data',
#    'gist-database',
#    'gist-db',
#    'github-database',
#    'key-value',
#    'keyvalue'],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 584208489,
#   'full_name': 'openbouffalo/buildroot_bouffalo',
#   'url': 'https://github.com/openbouffalo/buildroot_bouffalo',
#   'clone_url': 'https://github.com/openbouffalo/buildroot_bouffalo.git',
#   'watchers_count': 90,
#   'stargazers_count': 90,
#   'language': 'Python',
#   'forks': 16,
#   'created_at': '2023-01-01T20:49:38Z',
#   'updated_at': '2023-06-09T22:31:33Z',
#   'pushed_at': '2023-06-08T14:52:10Z',
#   'description': 'Linux Image for the BL808 CPU by Bouffalo Lab',
#   'languages_url': 'https://api.github.com/repos/openbouffalo/buildroot_bouffalo/languages',
#   'open_issues_count': 19,
#   'topics': ['bl808', 'bouffalolab'],
#   'license': None},
#  {'id': 584050943,
#   'full_name': 'Sorted1/FlipperStuff',
#   'url': 'https://github.com/Sorted1/FlipperStuff',
#   'clone_url': 'https://github.com/Sorted1/FlipperStuff.git',
#   'watchers_count': 90,
#   'stargazers_count': 90,
#   'language': 'Python',
#   'forks': 13,
#   'created_at': '2023-01-01T05:10:18Z',
#   'updated_at': '2023-06-13T13:40:51Z',
#   'pushed_at': '2023-05-31T06:29:58Z',
#   'description': 'All Things You Can Actively Use On Your Flipper Zero',
#   'languages_url': 'https://api.github.com/repos/Sorted1/FlipperStuff/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': None},
#  {'id': 584125419,
#   'full_name': 'Physical-Science-Academy/NoCheatPlus',
#   'url': 'https://github.com/Physical-Science-Academy/NoCheatPlus',
#   'clone_url': 'https://github.com/Physical-Science-Academy/NoCheatPlus.git',
#   'watchers_count': 89,
#   'stargazers_count': 89,
#   'language': 'Kotlin',
#   'forks': 8,
#   'created_at': '2023-01-01T13:35:36Z',
#   'updated_at': '2023-06-06T23:54:11Z',
#   'pushed_at': '2023-06-08T04:11:35Z',
#   'description': 'Anti-Cheat plugin for Minecraft (Nukkit/PM1E/PowerNukkitX)',
#   'languages_url': 'https://api.github.com/repos/Physical-Science-Academy/NoCheatPlus/languages',
#   'open_issues_count': 15,
#   'topics': ['anticheat',
#    'bedrock',
#    'mcbe',
#    'minecraft',
#    'ncp',
#    'nukkit',
#    'plugin'],
#   'license': {'key': 'gpl-3.0',
#    'name': 'GNU General Public License v3.0',
#    'spdx_id': 'GPL-3.0',
#    'url': 'https://api.github.com/licenses/gpl-3.0',
#    'node_id': 'MDc6TGljZW5zZTk='}},
#  {'id': 584208016,
#   'full_name': 'cloudclientdev/cloudclient',
#   'url': 'https://github.com/cloudclientdev/cloudclient',
#   'clone_url': 'https://github.com/cloudclientdev/cloudclient.git',
#   'watchers_count': 89,
#   'stargazers_count': 89,
#   'language': 'Java',
#   'forks': 28,
#   'created_at': '2023-01-01T20:46:42Z',
#   'updated_at': '2023-06-06T09:28:07Z',
#   'pushed_at': '2023-05-11T07:22:20Z',
#   'description': 'An open source Minecraft PVP Client',
#   'languages_url': 'https://api.github.com/repos/cloudclientdev/cloudclient/languages',
#   'open_issues_count': 12,
#   'topics': [],
#   'license': {'key': 'gpl-3.0',
#    'name': 'GNU General Public License v3.0',
#    'spdx_id': 'GPL-3.0',
#    'url': 'https://api.github.com/licenses/gpl-3.0',
#    'node_id': 'MDc6TGljZW5zZTk='}},
#  {'id': 584200680,
#   'full_name': 'xabblll/DoomInUnityInspector',
#   'url': 'https://github.com/xabblll/DoomInUnityInspector',
#   'clone_url': 'https://github.com/xabblll/DoomInUnityInspector.git',
#   'watchers_count': 87,
#   'stargazers_count': 87,
#   'language': 'C#',
#   'forks': 7,
#   'created_at': '2023-01-01T20:02:11Z',
#   'updated_at': '2023-05-31T01:52:07Z',
#   'pushed_at': '2023-01-06T22:42:51Z',
#   'description': None,
#   'languages_url': 'https://api.github.com/repos/xabblll/DoomInUnityInspector/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': None},
#  {'id': 584228988,
#   'full_name': 'marcosnils/awesome-playgrounds',
#   'url': 'https://github.com/marcosnils/awesome-playgrounds',
#   'clone_url': 'https://github.com/marcosnils/awesome-playgrounds.git',
#   'watchers_count': 86,
#   'stargazers_count': 86,
#   'language': None,
#   'forks': 7,
#   'created_at': '2023-01-01T23:10:24Z',
#   'updated_at': '2023-06-01T09:26:16Z',
#   'pushed_at': '2023-04-24T09:27:41Z',
#   'description': 'List of awesome playgrounds',
#   'languages_url': 'https://api.github.com/repos/marcosnils/awesome-playgrounds/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': None},
#  {'id': 584176399,
#   'full_name': 'weiyesing/QuantumultX',
#   'url': 'https://github.com/weiyesing/QuantumultX',
#   'clone_url': 'https://github.com/weiyesing/QuantumultX.git',
#   'watchers_count': 83,
#   'stargazers_count': 83,
#   'language': 'JavaScript',
#   'forks': 5,
#   'created_at': '2023-01-01T17:48:51Z',
#   'updated_at': '2023-06-16T01:34:29Z',
#   'pushed_at': '2023-06-15T03:17:09Z',
#   'description': '自用圈叉配置',
#   'languages_url': 'https://api.github.com/repos/weiyesing/QuantumultX/languages',
#   'open_issues_count': 0,
#   'topics': ['quantumultx'],
#   'license': None},
#  {'id': 584139370,
#   'full_name': 'corleytd/PyTorchBasic',
#   'url': 'https://github.com/corleytd/PyTorchBasic',
#   'clone_url': 'https://github.com/corleytd/PyTorchBasic.git',
#   'watchers_count': 80,
#   'stargazers_count': 80,
#   'language': 'Python',
#   'forks': 1,
#   'created_at': '2023-01-01T14:45:07Z',
#   'updated_at': '2023-05-23T23:38:01Z',
#   'pushed_at': '2023-01-13T04:55:20Z',
#   'description': 'This repository provides tutorial for deep learning researchers and PyTorch beginners to learn and practice PyTorch.',
#   'languages_url': 'https://api.github.com/repos/corleytd/PyTorchBasic/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': None},
#  {'id': 584138814,
#   'full_name': 'mostafaemara/real_time_vehicle_tracking_app',
#   'url': 'https://github.com/mostafaemara/real_time_vehicle_tracking_app',
#   'clone_url': 'https://github.com/mostafaemara/real_time_vehicle_tracking_app.git',
#   'watchers_count': 73,
#   'stargazers_count': 73,
#   'language': 'Dart',
#   'forks': 35,
#   'created_at': '2023-01-01T14:42:23Z',
#   'updated_at': '2023-05-16T17:31:43Z',
#   'pushed_at': '2023-01-05T10:12:04Z',
#   'description': None,
#   'languages_url': 'https://api.github.com/repos/mostafaemara/real_time_vehicle_tracking_app/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': None},
#  {'id': 584172068,
#   'full_name': 'avialxee/scoobi',
#   'url': 'https://github.com/avialxee/scoobi',
#   'clone_url': 'https://github.com/avialxee/scoobi.git',
#   'watchers_count': 70,
#   'stargazers_count': 70,
#   'language': 'Python',
#   'forks': 2,
#   'created_at': '2023-01-01T17:27:36Z',
#   'updated_at': '2023-05-26T09:16:39Z',
#   'pushed_at': '2023-05-24T19:54:48Z',
#   'description': 'Solar Conventionality-based Organizing Observation data ( SCOOBI ) for ARIES Nainital',
#   'languages_url': 'https://api.github.com/repos/avialxee/scoobi/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': {'key': 'bsd-3-clause',
#    'name': 'BSD 3-Clause "New" or "Revised" License',
#    'spdx_id': 'BSD-3-Clause',
#    'url': 'https://api.github.com/licenses/bsd-3-clause',
#    'node_id': 'MDc6TGljZW5zZTU='}},
#  {'id': 584155583,
#   'full_name': 'rajani103/90DaysOfDevOps',
#   'url': 'https://github.com/rajani103/90DaysOfDevOps',
#   'clone_url': 'https://github.com/rajani103/90DaysOfDevOps.git',
#   'watchers_count': 66,
#   'stargazers_count': 66,
#   'language': None,
#   'forks': 51,
#   'created_at': '2023-01-01T16:03:57Z',
#   'updated_at': '2023-06-15T19:44:51Z',
#   'pushed_at': '2023-04-13T11:21:45Z',
#   'description': '90DaysOfDevOps',
#   'languages_url': 'https://api.github.com/repos/rajani103/90DaysOfDevOps/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': None},
#  {'id': 584110511,
#   'full_name': 'hjyvip/xingtian',
#   'url': 'https://github.com/hjyvip/xingtian',
#   'clone_url': 'https://github.com/hjyvip/xingtian.git',
#   'watchers_count': 66,
#   'stargazers_count': 66,
#   'language': None,
#   'forks': 7,
#   'created_at': '2023-01-01T12:12:01Z',
#   'updated_at': '2023-06-16T00:43:31Z',
#   'pushed_at': '2023-06-11T03:10:00Z',
#   'description': 'VPN/proxy WIKI .Find the best VPN/proxy 免费的VPN 代理 账号 存档 翻墙 科学上网 梯子 机场 clash v2ray ss ssr vmess 免费V2Ray账号分享 翻墙 无界 自由门 八方云 SS账号 机场订阅地址🚀 免费共享♻️ 定期更新✨ 科学上网🌈 请勿滥用🚫一键订阅📪 hwanz/SSR-V2ray-Trojan-vpn 免费机场 公益机场 收集',
#   'languages_url': 'https://api.github.com/repos/hjyvip/xingtian/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': None},
#  {'id': 584231368,
#   'full_name': 'styppo/hamstr',
#   'url': 'https://github.com/styppo/hamstr',
#   'clone_url': 'https://github.com/styppo/hamstr.git',
#   'watchers_count': 62,
#   'stargazers_count': 62,
#   'language': 'Vue',
#   'forks': 26,
#   'created_at': '2023-01-01T23:28:51Z',
#   'updated_at': '2023-06-12T14:34:46Z',
#   'pushed_at': '2023-04-07T20:36:13Z',
#   'description': 'A twitter-style Nostr web client',
#   'languages_url': 'https://api.github.com/repos/styppo/hamstr/languages',
#   'open_issues_count': 30,
#   'topics': ['nostr'],
#   'license': None},
#  {'id': 584130270,
#   'full_name': '100DaysofYARA/2023',
#   'url': 'https://github.com/100DaysofYARA/2023',
#   'clone_url': 'https://github.com/100DaysofYARA/2023.git',
#   'watchers_count': 61,
#   'stargazers_count': 61,
#   'language': 'YARA',
#   'forks': 20,
#   'created_at': '2023-01-01T13:59:48Z',
#   'updated_at': '2023-06-08T21:06:48Z',
#   'pushed_at': '2023-04-12T01:44:57Z',
#   'description': 'Rules Shared by the Community from 100 Days of YARA 2023',
#   'languages_url': 'https://api.github.com/repos/100DaysofYARA/2023/languages',
#   'open_issues_count': 2,
#   'topics': [],
#   'license': None},
#  {'id': 584121432,
#   'full_name': 'JenifferMendes/projeto-jkode',
#   'url': 'https://github.com/JenifferMendes/projeto-jkode',
#   'clone_url': 'https://github.com/JenifferMendes/projeto-jkode.git',
#   'watchers_count': 59,
#   'stargazers_count': 59,
#   'language': None,
#   'forks': 0,
#   'created_at': '2023-01-01T13:13:54Z',
#   'updated_at': '2023-05-10T01:34:29Z',
#   'pushed_at': '2023-02-23T21:46:40Z',
#   'description': 'O projeto JKode tem como objetivo documentar todo meu progresso na jornada para me tornar uma Desenvolvedora Web.',
#   'languages_url': 'https://api.github.com/repos/JenifferMendes/projeto-jkode/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 584086367,
#   'full_name': 'FredyJabe/aeyama',
#   'url': 'https://github.com/FredyJabe/aeyama',
#   'clone_url': 'https://github.com/FredyJabe/aeyama.git',
#   'watchers_count': 57,
#   'stargazers_count': 57,
#   'language': 'Java',
#   'forks': 17,
#   'created_at': '2023-01-01T09:37:38Z',
#   'updated_at': '2023-06-15T16:42:17Z',
#   'pushed_at': '2023-06-15T15:50:51Z',
#   'description': "A mindustry mod that adds a new planet with it's own Techtree and Campaign!",
#   'languages_url': 'https://api.github.com/repos/FredyJabe/aeyama/languages',
#   'open_issues_count': 4,
#   'topics': ['hjson',
#    'javascript',
#    'mindustry-mod',
#    'mindustry-mod-v7',
#    'mod'],
#   'license': {'key': 'gpl-3.0',
#    'name': 'GNU General Public License v3.0',
#    'spdx_id': 'GPL-3.0',
#    'url': 'https://api.github.com/licenses/gpl-3.0',
#    'node_id': 'MDc6TGljZW5zZTk='}},
#  {'id': 584122596,
#   'full_name': 'ant-design/antd-style',
#   'url': 'https://github.com/ant-design/antd-style',
#   'clone_url': 'https://github.com/ant-design/antd-style.git',
#   'watchers_count': 56,
#   'stargazers_count': 56,
#   'language': 'TypeScript',
#   'forks': 13,
#   'created_at': '2023-01-01T13:20:06Z',
#   'updated_at': '2023-06-16T05:38:07Z',
#   'pushed_at': '2023-06-14T06:45:22Z',
#   'description': 'css-in-js library with antd v5 token system',
#   'languages_url': 'https://api.github.com/repos/ant-design/antd-style/languages',
#   'open_issues_count': 2,
#   'topics': ['antd', 'css-in-js', 'design-token'],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 584167315,
#   'full_name': 'zmedelis/bosquet',
#   'url': 'https://github.com/zmedelis/bosquet',
#   'clone_url': 'https://github.com/zmedelis/bosquet.git',
#   'watchers_count': 54,
#   'stargazers_count': 54,
#   'language': 'Clojure',
#   'forks': 3,
#   'created_at': '2023-01-01T17:03:29Z',
#   'updated_at': '2023-06-12T22:27:47Z',
#   'pushed_at': '2023-06-15T06:14:57Z',
#   'description': 'LLMOps tools to build, chain, evaluate and deploy prompts for GPT and other models.',
#   'languages_url': 'https://api.github.com/repos/zmedelis/bosquet/languages',
#   'open_issues_count': 5,
#   'topics': ['clojure', 'gpt', 'llmops', 'prompt', 'prompt-engineering'],
#   'license': {'key': 'epl-1.0',
#    'name': 'Eclipse Public License 1.0',
#    'spdx_id': 'EPL-1.0',
#    'url': 'https://api.github.com/licenses/epl-1.0',
#    'node_id': 'MDc6TGljZW5zZTc='}},
#  {'id': 584197204,
#   'full_name': 'ozancanozdemir/Turkiye-deki-Acik-Veri-Portallari-Open-Data-Portals-in-Turkey-',
#   'url': 'https://github.com/ozancanozdemir/Turkiye-deki-Acik-Veri-Portallari-Open-Data-Portals-in-Turkey-',
#   'clone_url': 'https://github.com/ozancanozdemir/Turkiye-deki-Acik-Veri-Portallari-Open-Data-Portals-in-Turkey-.git',
#   'watchers_count': 54,
#   'stargazers_count': 54,
#   'language': None,
#   'forks': 1,
#   'created_at': '2023-01-01T19:41:09Z',
#   'updated_at': '2023-06-11T19:39:01Z',
#   'pushed_at': '2023-01-31T14:10:46Z',
#   'description': None,
#   'languages_url': 'https://api.github.com/repos/ozancanozdemir/Turkiye-deki-Acik-Veri-Portallari-Open-Data-Portals-in-Turkey-/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': None},
#  {'id': 584079348,
#   'full_name': 'dai-shi/valtio-signal',
#   'url': 'https://github.com/dai-shi/valtio-signal',
#   'clone_url': 'https://github.com/dai-shi/valtio-signal.git',
#   'watchers_count': 53,
#   'stargazers_count': 53,
#   'language': 'TypeScript',
#   'forks': 0,
#   'created_at': '2023-01-01T08:48:12Z',
#   'updated_at': '2023-05-25T06:33:00Z',
#   'pushed_at': '2023-02-25T23:43:39Z',
#   'description': 'Another React binding for Valtio proxy state',
#   'languages_url': 'https://api.github.com/repos/dai-shi/valtio-signal/languages',
#   'open_issues_count': 1,
#   'topics': [],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 584076870,
#   'full_name': 'spencerwooo/clashrup',
#   'url': 'https://github.com/spencerwooo/clashrup',
#   'clone_url': 'https://github.com/spencerwooo/clashrup.git',
#   'watchers_count': 53,
#   'stargazers_count': 53,
#   'language': 'Rust',
#   'forks': 2,
#   'created_at': '2023-01-01T08:31:16Z',
#   'updated_at': '2023-06-13T12:33:17Z',
#   'pushed_at': '2023-06-14T21:26:04Z',
#   'description': 'Simple CLI to manage your systemd clash.service and config subscriptions on Linux.',
#   'languages_url': 'https://api.github.com/repos/spencerwooo/clashrup/languages',
#   'open_issues_count': 4,
#   'topics': ['clash', 'linux', 'proxy', 'systemd'],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 584038365,
#   'full_name': 'ShenZheng2000/LLIE_Survey',
#   'url': 'https://github.com/ShenZheng2000/LLIE_Survey',
#   'clone_url': 'https://github.com/ShenZheng2000/LLIE_Survey.git',
#   'watchers_count': 51,
#   'stargazers_count': 51,
#   'language': 'Python',
#   'forks': 4,
#   'created_at': '2023-01-01T03:11:50Z',
#   'updated_at': '2023-06-12T09:32:58Z',
#   'pushed_at': '2023-04-23T20:50:13Z',
#   'description': 'Resources for our paper "Low-Light Image and Video Enhancement: A Comprehensive Survey and Beyond"',
#   'languages_url': 'https://api.github.com/repos/ShenZheng2000/LLIE_Survey/languages',
#   'open_issues_count': 1,
#   'topics': [],
#   'license': None},
#  {'id': 584158114,
#   'full_name': 'thaitype/nammatham',
#   'url': 'https://github.com/thaitype/nammatham',
#   'clone_url': 'https://github.com/thaitype/nammatham.git',
#   'watchers_count': 50,
#   'stargazers_count': 50,
#   'language': 'TypeScript',
#   'forks': 2,
#   'created_at': '2023-01-01T16:16:58Z',
#   'updated_at': '2023-06-05T12:35:50Z',
#   'pushed_at': '2023-03-27T08:52:41Z',
#   'description': 'Azure Function Lightweight frameworks with DI, providing type safe function triggers and bindings',
#   'languages_url': 'https://api.github.com/repos/thaitype/nammatham/languages',
#   'open_issues_count': 24,
#   'topics': ['azure',
#    'azure-functions',
#    'dependency-injection',
#    'faas',
#    'functions',
#    'nodejs',
#    'serverless',
#    'typescript'],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 584225227,
#   'full_name': 'Ort0x36/Dimorf',
#   'url': 'https://github.com/Ort0x36/Dimorf',
#   'clone_url': 'https://github.com/Ort0x36/Dimorf.git',
#   'watchers_count': 49,
#   'stargazers_count': 49,
#   'language': 'Python',
#   'forks': 10,
#   'created_at': '2023-01-01T22:42:29Z',
#   'updated_at': '2023-05-31T16:50:13Z',
#   'pushed_at': '2023-06-02T12:14:15Z',
#   'description': 'Dimorf is a ransomware using 256-bit AES with a self-destructing, randomly generated key for Linux OS´s',
#   'languages_url': 'https://api.github.com/repos/Ort0x36/Dimorf/languages',
#   'open_issues_count': 0,
#   'topics': ['advanced-encryption-standard',
#    'aes-256',
#    'aes-encryption',
#    'cbc',
#    'hacking',
#    'hacking-tool',
#    'hacking-tools',
#    'linux',
#    'malware',
#    'malware-development',
#    'pentest',
#    'pentesting',
#    'programming',
#    'python',
#    'ransomware',
#    'readteam',
#    'security',
#    'security-audit',
#    'security-tools',
#    'stealth'],
#   'license': {'key': 'other',
#    'name': 'Other',
#    'spdx_id': 'NOASSERTION',
#    'url': None,
#    'node_id': 'MDc6TGljZW5zZTA='}},
#  {'id': 584165706,
#   'full_name': 'harshitethic/whatsapp-chatgpt',
#   'url': 'https://github.com/harshitethic/whatsapp-chatgpt',
#   'clone_url': 'https://github.com/harshitethic/whatsapp-chatgpt.git',
#   'watchers_count': 49,
#   'stargazers_count': 49,
#   'language': 'JavaScript',
#   'forks': 166,
#   'created_at': '2023-01-01T16:54:59Z',
#   'updated_at': '2023-06-10T08:08:48Z',
#   'pushed_at': '2023-04-10T16:49:49Z',
#   'description': 'This is a source code to build a WhatsApp bot using OpenAI bot and Node.js. The bot is capable of understanding natural language and providing information on various topics.',
#   'languages_url': 'https://api.github.com/repos/harshitethic/whatsapp-chatgpt/languages',
#   'open_issues_count': 7,
#   'topics': ['chatgpt', 'openai', 'whatsapp-bot'],
#   'license': None},
#  {'id': 584203846,
#   'full_name': 'rosszurowski/tandem',
#   'url': 'https://github.com/rosszurowski/tandem',
#   'clone_url': 'https://github.com/rosszurowski/tandem.git',
#   'watchers_count': 48,
#   'stargazers_count': 48,
#   'language': 'Go',
#   'forks': 1,
#   'created_at': '2023-01-01T20:20:44Z',
#   'updated_at': '2023-04-18T02:09:33Z',
#   'pushed_at': '2023-02-03T10:50:04Z',
#   'description': 'Parallel task runner for servers and long-running commands.',
#   'languages_url': 'https://api.github.com/repos/rosszurowski/tandem/languages',
#   'open_issues_count': 2,
#   'topics': ['concurrently', 'golang', 'make', 'parallel', 'watch'],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 584173691,
#   'full_name': 'wiidev/d2x-cios',
#   'url': 'https://github.com/wiidev/d2x-cios',
#   'clone_url': 'https://github.com/wiidev/d2x-cios.git',
#   'watchers_count': 45,
#   'stargazers_count': 45,
#   'language': 'C',
#   'forks': 1,
#   'created_at': '2023-01-01T17:35:39Z',
#   'updated_at': '2023-06-01T14:40:29Z',
#   'pushed_at': '2023-02-07T13:02:58Z',
#   'description': 'A custom IOS for the Wii and Wii-U console, i.e. an IOS modified to add some new features not available in the official IOS.',
#   'languages_url': 'https://api.github.com/repos/wiidev/d2x-cios/languages',
#   'open_issues_count': 0,
#   'topics': ['console',
#    'custom-ios',
#    'usb-devices',
#    'wii',
#    'wii-homebrew',
#    'wii-u',
#    'wii-u-homebrew'],
#   'license': {'key': 'other',
#    'name': 'Other',
#    'spdx_id': 'NOASSERTION',
#    'url': None,
#    'node_id': 'MDc6TGljZW5zZTA='}},
#  {'id': 584192349,
#   'full_name': 'TIHan/Oly',
#   'url': 'https://github.com/TIHan/Oly',
#   'clone_url': 'https://github.com/TIHan/Oly.git',
#   'watchers_count': 43,
#   'stargazers_count': 43,
#   'language': 'F#',
#   'forks': 1,
#   'created_at': '2023-01-01T19:12:56Z',
#   'updated_at': '2023-06-05T01:42:27Z',
#   'pushed_at': '2023-06-15T07:41:20Z',
#   'description': 'Oly Language Compiler and Runtime',
#   'languages_url': 'https://api.github.com/repos/TIHan/Oly/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 584052724,
#   'full_name': 'duyledat197/go-gen-tools',
#   'url': 'https://github.com/duyledat197/go-gen-tools',
#   'clone_url': 'https://github.com/duyledat197/go-gen-tools.git',
#   'watchers_count': 42,
#   'stargazers_count': 42,
#   'language': 'Go',
#   'forks': 0,
#   'created_at': '2023-01-01T05:26:09Z',
#   'updated_at': '2023-05-25T06:56:24Z',
#   'pushed_at': '2023-05-23T16:41:48Z',
#   'description': 'A Go code generator for grpc',
#   'languages_url': 'https://api.github.com/repos/duyledat197/go-gen-tools/languages',
#   'open_issues_count': 6,
#   'topics': ['architecture',
#    'clean-architecture',
#    'clean-code',
#    'ddd',
#    'ddd-architecture',
#    'ddd-patterns',
#    'generator',
#    'go',
#    'go-kit',
#    'go-library',
#    'golang',
#    'golang-examples',
#    'golang-tools',
#    'grpc',
#    'grpc-client',
#    'grpc-go',
#    'grpc-server',
#    'protobuf',
#    'protocol-buffers'],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 584084868,
#   'full_name': 'yong-pii/Spark-T12',
#   'url': 'https://github.com/yong-pii/Spark-T12',
#   'clone_url': 'https://github.com/yong-pii/Spark-T12.git',
#   'watchers_count': 40,
#   'stargazers_count': 40,
#   'language': 'C',
#   'forks': 9,
#   'created_at': '2023-01-01T09:27:01Z',
#   'updated_at': '2023-06-09T09:56:38Z',
#   'pushed_at': '2023-04-08T07:43:56Z',
#   'description': '基于STC8H系列的便携式T12电烙铁',
#   'languages_url': 'https://api.github.com/repos/yong-pii/Spark-T12/languages',
#   'open_issues_count': 2,
#   'topics': [],
#   'license': None},
#  {'id': 584088913,
#   'full_name': 'alitaslimi/cross-chain-monitoring',
#   'url': 'https://github.com/alitaslimi/cross-chain-monitoring',
#   'clone_url': 'https://github.com/alitaslimi/cross-chain-monitoring.git',
#   'watchers_count': 40,
#   'stargazers_count': 40,
#   'language': 'Python',
#   'forks': 32,
#   'created_at': '2023-01-01T09:55:09Z',
#   'updated_at': '2023-06-01T11:49:55Z',
#   'pushed_at': '2023-02-15T09:02:33Z',
#   'description': 'Cross Chain Monitoring Tool',
#   'languages_url': 'https://api.github.com/repos/alitaslimi/cross-chain-monitoring/languages',
#   'open_issues_count': 1,
#   'topics': ['blockchain',
#    'cryptocurrency',
#    'dashboard',
#    'data-analysis',
#    'flipside-crypto',
#    'pandas',
#    'plotly',
#    'streamlit'],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 584135837,
#   'full_name': 'giibeom/project-NMJ-renewal',
#   'url': 'https://github.com/giibeom/project-NMJ-renewal',
#   'clone_url': 'https://github.com/giibeom/project-NMJ-renewal.git',
#   'watchers_count': 38,
#   'stargazers_count': 38,
#   'language': 'Java',
#   'forks': 2,
#   'created_at': '2023-01-01T14:28:15Z',
#   'updated_at': '2023-06-08T10:35:37Z',
#   'pushed_at': '2023-03-13T14:50:20Z',
#   'description': '💻 프로젝트 - 놀먹자',
#   'languages_url': 'https://api.github.com/repos/giibeom/project-NMJ-renewal/languages',
#   'open_issues_count': 4,
#   'topics': [],
#   'license': None},
#  {'id': 584190320,
#   'full_name': 'Halvani/Constituent-Treelib',
#   'url': 'https://github.com/Halvani/Constituent-Treelib',
#   'clone_url': 'https://github.com/Halvani/Constituent-Treelib.git',
#   'watchers_count': 38,
#   'stargazers_count': 38,
#   'language': 'Jupyter Notebook',
#   'forks': 8,
#   'created_at': '2023-01-01T19:01:28Z',
#   'updated_at': '2023-06-12T18:21:01Z',
#   'pushed_at': '2023-03-24T01:24:01Z',
#   'description': 'A lightweight Python library for constructing, processing, and visualizing constituent trees.',
#   'languages_url': 'https://api.github.com/repos/Halvani/Constituent-Treelib/languages',
#   'open_issues_count': 1,
#   'topics': ['constituency-parser',
#    'constituency-tree',
#    'export-to-pdf',
#    'visualization'],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 584106065,
#   'full_name': 'AKD-01/blogweet',
#   'url': 'https://github.com/AKD-01/blogweet',
#   'clone_url': 'https://github.com/AKD-01/blogweet.git',
#   'watchers_count': 37,
#   'stargazers_count': 37,
#   'language': 'JavaScript',
#   'forks': 156,
#   'created_at': '2023-01-01T11:46:46Z',
#   'updated_at': '2023-06-16T06:42:20Z',
#   'pushed_at': '2023-06-16T06:52:42Z',
#   'description': 'BlogWeet is a user-friendly social media app for creating, posting, and sharing blogs.',
#   'languages_url': 'https://api.github.com/repos/AKD-01/blogweet/languages',
#   'open_issues_count': 127,
#   'topics': ['blog', 'css3', 'firebase', 'reactjs'],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 584126101,
#   'full_name': 'luchanos/luchanos_oxford_university',
#   'url': 'https://github.com/luchanos/luchanos_oxford_university',
#   'clone_url': 'https://github.com/luchanos/luchanos_oxford_university.git',
#   'watchers_count': 36,
#   'stargazers_count': 36,
#   'language': 'Python',
#   'forks': 14,
#   'created_at': '2023-01-01T13:39:00Z',
#   'updated_at': '2023-06-11T17:54:22Z',
#   'pushed_at': '2023-04-29T17:44:45Z',
#   'description': None,
#   'languages_url': 'https://api.github.com/repos/luchanos/luchanos_oxford_university/languages',
#   'open_issues_count': 4,
#   'topics': [],
#   'license': None},
#  {'id': 584212506,
#   'full_name': 'AI4Finance-Foundation/FinRL-Blogs',
#   'url': 'https://github.com/AI4Finance-Foundation/FinRL-Blogs',
#   'clone_url': 'https://github.com/AI4Finance-Foundation/FinRL-Blogs.git',
#   'watchers_count': 36,
#   'stargazers_count': 36,
#   'language': None,
#   'forks': 11,
#   'created_at': '2023-01-01T21:15:34Z',
#   'updated_at': '2023-06-08T08:25:55Z',
#   'pushed_at': '2023-04-16T23:50:12Z',
#   'description': 'Blogs, tutorials, news. Please star.',
#   'languages_url': 'https://api.github.com/repos/AI4Finance-Foundation/FinRL-Blogs/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': None},
#  {'id': 584033064,
#   'full_name': 'morleydragon/eecs489',
#   'url': 'https://github.com/morleydragon/eecs489',
#   'clone_url': 'https://github.com/morleydragon/eecs489.git',
#   'watchers_count': 34,
#   'stargazers_count': 34,
#   'language': 'C++',
#   'forks': 27,
#   'created_at': '2023-01-01T02:19:00Z',
#   'updated_at': '2023-05-30T03:30:24Z',
#   'pushed_at': '2023-04-21T13:25:54Z',
#   'description': None,
#   'languages_url': 'https://api.github.com/repos/morleydragon/eecs489/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': {'key': 'gpl-3.0',
#    'name': 'GNU General Public License v3.0',
#    'spdx_id': 'GPL-3.0',
#    'url': 'https://api.github.com/licenses/gpl-3.0',
#    'node_id': 'MDc6TGljZW5zZTk='}},
#  {'id': 584177526,
#   'full_name': 'acorn1010/render',
#   'url': 'https://github.com/acorn1010/render',
#   'clone_url': 'https://github.com/acorn1010/render.git',
#   'watchers_count': 34,
#   'stargazers_count': 34,
#   'language': 'TypeScript',
#   'forks': 2,
#   'created_at': '2023-01-01T17:54:24Z',
#   'updated_at': '2023-06-15T22:29:51Z',
#   'pushed_at': '2023-05-13T23:04:32Z',
#   'description': None,
#   'languages_url': 'https://api.github.com/repos/acorn1010/render/languages',
#   'open_issues_count': 3,
#   'topics': [],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 584066469,
#   'full_name': 'ColdHeat/nycts-unit',
#   'url': 'https://github.com/ColdHeat/nycts-unit',
#   'clone_url': 'https://github.com/ColdHeat/nycts-unit.git',
#   'watchers_count': 33,
#   'stargazers_count': 33,
#   'language': 'JavaScript',
#   'forks': 2,
#   'created_at': '2023-01-01T07:15:05Z',
#   'updated_at': '2023-05-03T14:52:51Z',
#   'pushed_at': '2023-01-01T07:20:12Z',
#   'description': 'This is the code that ran on the Raspberry Pi that powered the NYCTrainSign. The authors had full git history on the MicroSD card and this is the copy of that.',
#   'languages_url': 'https://api.github.com/repos/ColdHeat/nycts-unit/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': None},
#  {'id': 584024363,
#   'full_name': 'iAsure/discord-arts',
#   'url': 'https://github.com/iAsure/discord-arts',
#   'clone_url': 'https://github.com/iAsure/discord-arts.git',
#   'watchers_count': 33,
#   'stargazers_count': 33,
#   'language': 'JavaScript',
#   'forks': 4,
#   'created_at': '2023-01-01T00:49:22Z',
#   'updated_at': '2023-06-12T20:36:29Z',
#   'pushed_at': '2023-06-16T09:01:06Z',
#   'description': 'Customized cards with Discord style',
#   'languages_url': 'https://api.github.com/repos/iAsure/discord-arts/languages',
#   'open_issues_count': 2,
#   'topics': ['canvas', 'discord', 'nodejs'],
#   'license': None},
#  {'id': 584022500,
#   'full_name': 'acantril/kubernetes-fundamentals',
#   'url': 'https://github.com/acantril/kubernetes-fundamentals',
#   'clone_url': 'https://github.com/acantril/kubernetes-fundamentals.git',
#   'watchers_count': 33,
#   'stargazers_count': 33,
#   'language': None,
#   'forks': 2,
#   'created_at': '2023-01-01T00:30:27Z',
#   'updated_at': '2023-05-26T11:34:31Z',
#   'pushed_at': '2023-01-01T00:30:28Z',
#   'description': 'Course Assets for https://learn.cantrill.io/p/kubernetes-fundamentals/',
#   'languages_url': 'https://api.github.com/repos/acantril/kubernetes-fundamentals/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 584172862,
#   'full_name': 'rounit08/frontendfighters',
#   'url': 'https://github.com/rounit08/frontendfighters',
#   'clone_url': 'https://github.com/rounit08/frontendfighters.git',
#   'watchers_count': 33,
#   'stargazers_count': 33,
#   'language': 'JavaScript',
#   'forks': 3,
#   'created_at': '2023-01-01T17:31:39Z',
#   'updated_at': '2023-06-14T13:22:48Z',
#   'pushed_at': '2023-06-13T15:06:39Z',
#   'description': 'This repo consists of challenges for FrontEnd Dev, developed using HTML, CSS, JS. {Sources: Sunny Puri\'s "the-dom-challenge" (Repo Link:  https://github.com/devkodeio/the-dom-challenge) , adding all the problems + solutions of BFE.com and INTERNET}',
#   'languages_url': 'https://api.github.com/repos/rounit08/frontendfighters/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': None},
#  {'id': 584222414,
#   'full_name': 'atilatech/atila-core-service',
#   'url': 'https://github.com/atilatech/atila-core-service',
#   'clone_url': 'https://github.com/atilatech/atila-core-service.git',
#   'watchers_count': 32,
#   'stargazers_count': 32,
#   'language': 'Jupyter Notebook',
#   'forks': 1,
#   'created_at': '2023-01-01T22:22:12Z',
#   'updated_at': '2023-06-09T06:14:38Z',
#   'pushed_at': '2023-06-06T16:44:25Z',
#   'description': 'The primary backend service for Atila apps.',
#   'languages_url': 'https://api.github.com/repos/atilatech/atila-core-service/languages',
#   'open_issues_count': 4,
#   'topics': ['django', 'postgres', 'postgresql', 'python'],
#   'license': {'key': 'gpl-3.0',
#    'name': 'GNU General Public License v3.0',
#    'spdx_id': 'GPL-3.0',
#    'url': 'https://api.github.com/licenses/gpl-3.0',
#    'node_id': 'MDc6TGljZW5zZTk='}},
#  {'id': 584092941,
#   'full_name': 'geocine/sd-easy-mode',
#   'url': 'https://github.com/geocine/sd-easy-mode',
#   'clone_url': 'https://github.com/geocine/sd-easy-mode.git',
#   'watchers_count': 32,
#   'stargazers_count': 32,
#   'language': 'Python',
#   'forks': 8,
#   'created_at': '2023-01-01T10:22:21Z',
#   'updated_at': '2023-06-01T13:26:39Z',
#   'pushed_at': '2023-04-29T09:46:07Z',
#   'description': 'Easy Mode Stable Diffusion process allows you to generate images based on your own photos in just three steps',
#   'languages_url': 'https://api.github.com/repos/geocine/sd-easy-mode/languages',
#   'open_issues_count': 5,
#   'topics': ['dreambooth', 'stable-diffusion'],
#   'license': None},
#  {'id': 584078434,
#   'full_name': 'bukaleyang/zhongkui-waf',
#   'url': 'https://github.com/bukaleyang/zhongkui-waf',
#   'clone_url': 'https://github.com/bukaleyang/zhongkui-waf.git',
#   'watchers_count': 31,
# ...
#   'pushed_at': '2023-01-01T10:29:09Z',
#   'description': 'shell 学习笔记',
#   'languages_url': 'https://api.github.com/repos/lcd-first/shell/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': None},
#  {'id': 584096763,
#   'full_name': 'Jock3r99/Maths-Game',
#   'url': 'https://github.com/Jock3r99/Maths-Game',
#   'clone_url': 'https://github.com/Jock3r99/Maths-Game.git',
#   'watchers_count': 3,
#   'stargazers_count': 3,
#   'language': 'Python',
#   'forks': 0,
#   'created_at': '2023-01-01T10:47:29Z',
#   'updated_at': '2023-01-04T18:29:04Z',
#   'pushed_at': '2023-01-01T11:29:21Z',
#   'description': 'A Maths Game Made With Python By Clown ~ Pain',
#   'languages_url': 'https://api.github.com/repos/Jock3r99/Maths-Game/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': None},
#  {'id': 584219186,
#   'full_name': 'santoshyadavdev/ci-action-exercise',
#   'url': 'https://github.com/santoshyadavdev/ci-action-exercise',
#   'clone_url': 'https://github.com/santoshyadavdev/ci-action-exercise.git',
#   'watchers_count': 3,
#   'stargazers_count': 3,
#   'language': None,
#   'forks': 0,
#   'created_at': '2023-01-01T21:59:57Z',
#   'updated_at': '2023-04-04T01:59:19Z',
#   'pushed_at': '2023-01-01T22:21:23Z',
#   'description': None,
#   'languages_url': 'https://api.github.com/repos/santoshyadavdev/ci-action-exercise/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': {'key': 'cc-by-4.0',
#    'name': 'Creative Commons Attribution 4.0 International',
#    'spdx_id': 'CC-BY-4.0',
#    'url': 'https://api.github.com/licenses/cc-by-4.0',
#    'node_id': 'MDc6TGljZW5zZTI1'}},
#  {'id': 584037462,
#   'full_name': 'amymartika/novelgens-data-analysis',
#   'url': 'https://github.com/amymartika/novelgens-data-analysis',
#   'clone_url': 'https://github.com/amymartika/novelgens-data-analysis.git',
#   'watchers_count': 3,
#   'stargazers_count': 3,
#   'language': None,
#   'forks': 0,
#   'created_at': '2023-01-01T03:03:21Z',
#   'updated_at': '2023-03-02T03:39:02Z',
#   'pushed_at': '2023-03-29T00:52:07Z',
#   'description': 'How do we perceive AI-generated creatures?',
#   'languages_url': 'https://api.github.com/repos/amymartika/novelgens-data-analysis/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': None},
#  {'id': 584075942,
#   'full_name': 'usuyuki/rawp',
#   'url': 'https://github.com/usuyuki/rawp',
#   'clone_url': 'https://github.com/usuyuki/rawp.git',
#   'watchers_count': 3,
#   'stargazers_count': 3,
#   'language': 'TypeScript',
#   'forks': 0,
#   'created_at': '2023-01-01T08:24:45Z',
#   'updated_at': '2023-05-01T05:52:54Z',
#   'pushed_at': '2023-03-21T01:50:22Z',
#   'description': 'RAWPは重複を減らした複数回グループ分けを焼きなまし法で行うツールです。クライアントでWASM経由で実行されます。',
#   'languages_url': 'https://api.github.com/repos/usuyuki/rawp/languages',
#   'open_issues_count': 6,
#   'topics': ['nextjs', 'rust', 'webassembly'],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 584113393,
#   'full_name': 'notnavindu/adafruit-macropad-hotkeys-with-extensions',
#   'url': 'https://github.com/notnavindu/adafruit-macropad-hotkeys-with-extensions',
#   'clone_url': 'https://github.com/notnavindu/adafruit-macropad-hotkeys-with-extensions.git',
#   'watchers_count': 3,
#   'stargazers_count': 3,
#   'language': 'Python',
#   'forks': 0,
#   'created_at': '2023-01-01T12:28:37Z',
#   'updated_at': '2023-05-21T18:35:02Z',
#   'pushed_at': '2023-01-18T04:10:36Z',
#   'description': None,
#   'languages_url': 'https://api.github.com/repos/notnavindu/adafruit-macropad-hotkeys-with-extensions/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': {'key': 'gpl-3.0',
#    'name': 'GNU General Public License v3.0',
#    'spdx_id': 'GPL-3.0',
#    'url': 'https://api.github.com/licenses/gpl-3.0',
#    'node_id': 'MDc6TGljZW5zZTk='}},
#  {'id': 584119179,
#   'full_name': 'Chendemo12/functools',
#   'url': 'https://github.com/Chendemo12/functools',
#   'clone_url': 'https://github.com/Chendemo12/functools.git',
#   'watchers_count': 3,
#   'stargazers_count': 3,
#   'language': 'Go',
#   'forks': 0,
#   'created_at': '2023-01-01T13:01:43Z',
#   'updated_at': '2023-02-12T15:10:00Z',
#   'pushed_at': '2023-05-25T11:54:29Z',
#   'description': 'go functools',
#   'languages_url': 'https://api.github.com/repos/Chendemo12/functools/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': None},
#  {'id': 584093554,
#   'full_name': 'OlimilO1402/Langg_Nullable',
#   'url': 'https://github.com/OlimilO1402/Langg_Nullable',
#   'clone_url': 'https://github.com/OlimilO1402/Langg_Nullable.git',
#   'watchers_count': 3,
#   'stargazers_count': 3,
#   'language': 'Visual Basic 6.0',
#   'forks': 1,
#   'created_at': '2023-01-01T10:26:18Z',
#   'updated_at': '2023-01-09T06:57:37Z',
#   'pushed_at': '2023-05-27T15:45:04Z',
#   'description': 'How to make values optional and how to deal with it',
#   'languages_url': 'https://api.github.com/repos/OlimilO1402/Langg_Nullable/languages',
#   'open_issues_count': 0,
#   'topics': ['mandatory', 'nullable', 'optional'],
#   'license': {'key': 'gpl-3.0',
#    'name': 'GNU General Public License v3.0',
#    'spdx_id': 'GPL-3.0',
#    'url': 'https://api.github.com/licenses/gpl-3.0',
#    'node_id': 'MDc6TGljZW5zZTk='}},
#  {'id': 584193639,
#   'full_name': 'ioatzi/LIDL-Storyland-audiobox-tutorial',
#   'url': 'https://github.com/ioatzi/LIDL-Storyland-audiobox-tutorial',
#   'clone_url': 'https://github.com/ioatzi/LIDL-Storyland-audiobox-tutorial.git',
#   'watchers_count': 3,
#   'stargazers_count': 3,
#   'language': 'C++',
#   'forks': 0,
#   'created_at': '2023-01-01T19:20:15Z',
#   'updated_at': '2023-06-01T20:27:25Z',
#   'pushed_at': '2023-01-07T22:40:20Z',
#   'description': 'In this repository decribe how to add new audio track in LIDL Storyland and write new nfc tags with arduino and PN532',
#   'languages_url': 'https://api.github.com/repos/ioatzi/LIDL-Storyland-audiobox-tutorial/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': None},
#  {'id': 584129107,
#   'full_name': 'SNIPPIK/SPNK-DL',
#   'url': 'https://github.com/SNIPPIK/SPNK-DL',
#   'clone_url': 'https://github.com/SNIPPIK/SPNK-DL.git',
#   'watchers_count': 3,
#   'stargazers_count': 3,
#   'language': 'TypeScript',
#   'forks': 0,
#   'created_at': '2023-01-01T13:53:52Z',
#   'updated_at': '2023-04-12T21:48:35Z',
#   'pushed_at': '2023-06-01T20:27:39Z',
#   'description': 'YouTube video downloader',
#   'languages_url': 'https://api.github.com/repos/SNIPPIK/SPNK-DL/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 584035007,
#   'full_name': 'Thennavan-Hex/newyear_bot',
#   'url': 'https://github.com/Thennavan-Hex/newyear_bot',
#   'clone_url': 'https://github.com/Thennavan-Hex/newyear_bot.git',
#   'watchers_count': 3,
#   'stargazers_count': 3,
#   'language': 'Python',
#   'forks': 1,
#   'created_at': '2023-01-01T02:38:48Z',
#   'updated_at': '2023-03-29T05:44:05Z',
#   'pushed_at': '2023-01-18T13:18:08Z',
#   'description': 'resolution bot ',
#   'languages_url': 'https://api.github.com/repos/Thennavan-Hex/newyear_bot/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': None},
#  {'id': 584057902,
#   'full_name': 'SideStore/.github',
#   'url': 'https://github.com/SideStore/.github',
#   'clone_url': 'https://github.com/SideStore/.github.git',
#   'watchers_count': 3,
#   'stargazers_count': 3,
#   'language': None,
#   'forks': 1,
#   'created_at': '2023-01-01T06:08:57Z',
#   'updated_at': '2023-02-15T10:48:02Z',
#   'pushed_at': '2023-06-16T05:17:05Z',
#   'description': 'GitHub organization profile page',
#   'languages_url': 'https://api.github.com/repos/SideStore/.github/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 584201094,
#   'full_name': 'WagnerFFreitas/PraticandoHTML02',
#   'url': 'https://github.com/WagnerFFreitas/PraticandoHTML02',
#   'clone_url': 'https://github.com/WagnerFFreitas/PraticandoHTML02.git',
#   'watchers_count': 2,
#   'stargazers_count': 2,
#   'language': 'HTML',
#   'forks': 0,
#   'created_at': '2023-01-01T20:04:29Z',
#   'updated_at': '2023-02-27T07:21:57Z',
#   'pushed_at': '2023-01-01T20:24:20Z',
#   'description': 'Curso Cultura Educacional',
#   'languages_url': 'https://api.github.com/repos/WagnerFFreitas/PraticandoHTML02/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'}},
#  {'id': 584199101,
#   'full_name': 'So871/Multi-io',
#   'url': 'https://github.com/So871/Multi-io',
#   'clone_url': 'https://github.com/So871/Multi-io.git',
#   'watchers_count': 2,
#   'stargazers_count': 2,
#   'language': None,
#   'forks': 0,
#   'created_at': '2023-01-01T19:52:16Z',
#   'updated_at': '2023-02-27T07:22:02Z',
#   'pushed_at': '2023-01-01T19:59:43Z',
#   'description': 'A custom PCB with multi NTC and ds18b20, ',
#   'languages_url': 'https://api.github.com/repos/So871/Multi-io/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': None},
#  {'id': 584199619,
#   'full_name': 'Himanshu7905847404/voice-translator-',
#   'url': 'https://github.com/Himanshu7905847404/voice-translator-',
#   'clone_url': 'https://github.com/Himanshu7905847404/voice-translator-.git',
#   'watchers_count': 2,
#   'stargazers_count': 2,
#   'language': 'Python',
#   'forks': 0,
#   'created_at': '2023-01-01T19:55:42Z',
#   'updated_at': '2023-02-27T07:22:01Z',
#   'pushed_at': '2023-01-01T20:00:54Z',
#   'description': None,
#   'languages_url': 'https://api.github.com/repos/Himanshu7905847404/voice-translator-/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': None},
#  {'id': 584164987,
#   'full_name': 'rmkrepo/pub',
#   'url': 'https://github.com/rmkrepo/pub',
#   'clone_url': 'https://github.com/rmkrepo/pub.git',
#   'watchers_count': 2,
#   'stargazers_count': 2,
#   'language': None,
#   'forks': 0,
#   'created_at': '2023-01-01T16:51:20Z',
#   'updated_at': '2023-02-27T07:22:23Z',
#   'pushed_at': '2023-01-01T18:26:05Z',
#   'description': None,
#   'languages_url': 'https://api.github.com/repos/rmkrepo/pub/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='}},
#  {'id': 584159215,
#   'full_name': 'infinitesrivastava/instagramclone',
#   'url': 'https://github.com/infinitesrivastava/instagramclone',
#   'clone_url': 'https://github.com/infinitesrivastava/instagramclone.git',
#   'watchers_count': 2,
#   'stargazers_count': 2,
#   'language': 'HTML',
#   'forks': 0,
#   'created_at': '2023-01-01T16:22:21Z',
#   'updated_at': '2023-02-27T07:22:33Z',
#   'pushed_at': '2023-01-01T16:22:25Z',
#   'description': 'Created with CodeSandbox',
#   'languages_url': 'https://api.github.com/repos/infinitesrivastava/instagramclone/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': None},
#  {'id': 584162003,
#   'full_name': 'andrii-venher/PasswordFinder',
#   'url': 'https://github.com/andrii-venher/PasswordFinder',
#   'clone_url': 'https://github.com/andrii-venher/PasswordFinder.git',
#   'watchers_count': 2,
#   'stargazers_count': 2,
#   'language': 'OCaml',
#   'forks': 0,
#   'created_at': '2023-01-01T16:36:45Z',
#   'updated_at': '2023-02-27T07:22:29Z',
#   'pushed_at': '2023-01-01T16:51:45Z',
#   'description': 'Multicore password brute-force attack using distributed computations and message passing.',
#   'languages_url': 'https://api.github.com/repos/andrii-venher/PasswordFinder/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': None},
#  {'id': 584189324,
#   'full_name': 'Jmartnz/kata-prime-factors',
#   'url': 'https://github.com/Jmartnz/kata-prime-factors',
#   'clone_url': 'https://github.com/Jmartnz/kata-prime-factors.git',
#   'watchers_count': 2,
#   'stargazers_count': 2,
#   'language': 'Java',
#   'forks': 0,
#   'created_at': '2023-01-01T18:55:32Z',
#   'updated_at': '2023-02-27T07:22:11Z',
#   'pushed_at': '2023-01-01T19:10:18Z',
#   'description': 'The Prime Factors kata from Uncle Bob',
#   'languages_url': 'https://api.github.com/repos/Jmartnz/kata-prime-factors/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': None},
#  {'id': 584099787,
#   'full_name': 'dassudip2001/spring-docker-kubernetes',
#   'url': 'https://github.com/dassudip2001/spring-docker-kubernetes',
#   'clone_url': 'https://github.com/dassudip2001/spring-docker-kubernetes.git',
#   'watchers_count': 2,
#   'stargazers_count': 2,
#   'language': 'Java',
#   'forks': 0,
#   'created_at': '2023-01-01T11:07:39Z',
#   'updated_at': '2023-02-28T10:04:59Z',
#   'pushed_at': '2023-01-01T11:08:30Z',
#   'description': 'This repo create for rest api ',
#   'languages_url': 'https://api.github.com/repos/dassudip2001/spring-docker-kubernetes/languages',
#   'open_issues_count': 0,
#   'topics': ['docker',
#    'docker-compose',
#    'java',
#    'kubernetes',
#    'mysql',
#    'restapi',
#    'springboot'],
#   'license': None},
#  {'id': 584105740,
#   'full_name': 'PAOPLAKEM/WEB',
#   'url': 'https://github.com/PAOPLAKEM/WEB',
#   'clone_url': 'https://github.com/PAOPLAKEM/WEB.git',
#   'watchers_count': 2,
#   'stargazers_count': 2,
#   'language': 'PHP',
#   'forks': 0,
#   'created_at': '2023-01-01T11:45:04Z',
#   'updated_at': '2023-02-28T10:04:55Z',
#   'pushed_at': '2023-01-01T11:45:17Z',
#   'description': None,
#   'languages_url': 'https://api.github.com/repos/PAOPLAKEM/WEB/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': None},
#  {'id': 584098731,
#   'full_name': 'samerabed/HTML-CSS-project',
#   'url': 'https://github.com/samerabed/HTML-CSS-project',
#   'clone_url': 'https://github.com/samerabed/HTML-CSS-project.git',
#   'watchers_count': 2,
#   'stargazers_count': 2,
#   'language': 'HTML',
#   'forks': 0,
#   'created_at': '2023-01-01T11:01:02Z',
#   'updated_at': '2023-02-28T10:04:52Z',
#   'pushed_at': '2023-01-01T11:58:09Z',
#   'description': None,
#   'languages_url': 'https://api.github.com/repos/samerabed/HTML-CSS-project/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': None},
#  {'id': 584071848,
#   'full_name': 'islamdinidavetcileri/islamdinidavetcileri',
#   'url': 'https://github.com/islamdinidavetcileri/islamdinidavetcileri',
#   'clone_url': 'https://github.com/islamdinidavetcileri/islamdinidavetcileri.git',
#   'watchers_count': 2,
#   'stargazers_count': 2,
#   'language': None,
#   'forks': 0,
#   'created_at': '2023-01-01T07:54:44Z',
#   'updated_at': '2023-02-28T10:05:27Z',
#   'pushed_at': '2023-01-01T08:05:27Z',
#   'description': 'Config files for my GitHub profile.',
#   'languages_url': 'https://api.github.com/repos/islamdinidavetcileri/islamdinidavetcileri/languages',
#   'open_issues_count': 0,
#   'topics': ['config', 'github-config'],
#   'license': None},
#  {'id': 584060590,
#   'full_name': 'kholhilmy/Website-Pasar',
#   'url': 'https://github.com/kholhilmy/Website-Pasar',
#   'clone_url': 'https://github.com/kholhilmy/Website-Pasar.git',
#   'watchers_count': 2,
#   'stargazers_count': 2,
#   'language': 'JavaScript',
#   'forks': 0,
#   'created_at': '2023-01-01T06:31:00Z',
#   'updated_at': '2023-02-28T10:05:31Z',
#   'pushed_at': '2023-01-01T07:23:10Z',
#   'description': None,
#   'languages_url': 'https://api.github.com/repos/kholhilmy/Website-Pasar/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': None},
#  {'id': 584069214,
#   'full_name': 'SQUADGAMIN/improved-free-fire',
#   'url': 'https://github.com/SQUADGAMIN/improved-free-fire',
#   'clone_url': 'https://github.com/SQUADGAMIN/improved-free-fire.git',
#   'watchers_count': 2,
#   'stargazers_count': 2,
#   'language': None,
#   'forks': 0,
#   'created_at': '2023-01-01T07:35:34Z',
#   'updated_at': '2023-02-28T10:05:29Z',
#   'pushed_at': '2023-01-01T07:35:35Z',
#   'description': None,
#   'languages_url': 'https://api.github.com/repos/SQUADGAMIN/improved-free-fire/languages',
#   'open_issues_count': 0,
#   'topics': [],
#   'license': None},
#  ...]

# %%
df = pd.DataFrame.from_dict(repositories)
#df.to_csv('C:\\csv-data-collect\\github-2023.csv')
df.duplicated()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 3
#       1 df = pd.DataFrame.from_dict(repositories)
#       2 #df.to_csv('C:\\csv-data-collect\\github-2023.csv')
# ----> 3 df.duplicated()
#
# File c:\Users\Youcode\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:6672, in DataFrame.duplicated(self, subset, keep)
#    6670 else:
#    6671     vals = (col.values for name, col in self.items() if name in subset)
# -> 6672     labels, shape = map(list, zip(*map(f, vals)))
#    6674     ids = get_group_index(
#    6675         labels,
#    6676         # error: Argument 1 to "tuple" has incompatible type "List[_T]";
#    (...)
#    6680         xnull=False,
#    6681     )
#    6682     result = self._constructor_sliced(duplicated(ids, keep), index=self.index)
#
# File c:\Users\Youcode\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:6640, in DataFrame.duplicated.<locals>.f(vals)
#    6639 def f(vals) -> tuple[np.ndarray, int]:
# -> 6640     labels, shape = algorithms.factorize(vals, size_hint=len(self))
#    6641     return labels.astype("i8", copy=False), len(shape)
#
# File c:\Users\Youcode\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\algorithms.py:779, in factorize(values, sort, use_na_sentinel, size_hint)
#     776             # Don't modify (potentially user-provided) array
#     777             values = np.where(null_mask, na_value, values)
# --> 779     codes, uniques = factorize_array(
#     780         values,
#     781         use_na_sentinel=use_na_sentinel,
#     782         size_hint=size_hint,
#     783     )
#     785 if sort and len(uniques) > 0:
#     786     uniques, codes = safe_sort(
#     787         uniques,
#     788         codes,
#    (...)
#     791         verify=False,
#     792     )
#
# File c:\Users\Youcode\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\algorithms.py:580, in factorize_array(values, use_na_sentinel, size_hint, na_value, mask)
#     577 hash_klass, values = _get_hashtable_algo(values)
#     579 table = hash_klass(size_hint or len(values))
# --> 580 uniques, codes = table.factorize(
#     581     values,
#     582     na_sentinel=-1,
#     583     na_value=na_value,
#     584     mask=mask,
#     585     ignore_na=use_na_sentinel,
#     586 )
#     588 # re-cast e.g. i8->dt64/td64, uint8->bool
#     589 uniques = _reconstruct_data(uniques, original.dtype, original)
#
# File pandas\_libs\hashtable_class_helper.pxi:7280, in pandas._libs.hashtable.PyObjectHashTable.factorize()
#
# File pandas\_libs\hashtable_class_helper.pxi:7194, in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'
